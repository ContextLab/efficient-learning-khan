# %% [markdown]
# ## Imports

# %%
import re
import traceback
from collections import defaultdict
from difflib import get_close_matches

import hypertools as hyp
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from tqdm.notebook import tqdm

from khan_helpers import Experiment, Participant
from khan_helpers.constants import DATA_DIR, FIG_DIR, RAW_DIR
from khan_helpers.functions import (
    corr_mean,
    interp_lecture, 
    parse_windows,
    preprocess_text
)

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.patches import ConnectionPatch
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# %matplotlib inline
# Out:
# Experiment & Participant classes, helper functions, and variables used across multiple notebooks can be found in `/mnt/code/khan_helpers/khan_helpers`, or on GitHub, [here](https://github.com/contextlab/efficient-learning-khan/tree/master/code/khan_helpers).<br />You can also view source code directly from the notebook with:<br /><pre>    from khan_helpers.functions import show_source<br />    show_source(foo)</pre>

# %% [markdown]
# # TEMPORARY CELLS

# %%
try:
    del interp_lecture
    del parse_windows
    del preprocess_text
except NameError:
    pass

from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# from num2words import num2words as _num2words
from khan_helpers.functions import _ts_to_sec, synset_match

# %%
def parse_windows(transcript, wsize):
    lines = transcript.splitlines()
    text_lines = lines[1::2]
    ts_lines = np.array(list(map(_ts_to_sec, lines[::2])))
    windows = []
    timestamps = []
    for ix in range(1, wsize):
        start, end = 0, ix
        windows.append(' '.join(text_lines[start:end]))
        timestamps.append((ts_lines[start] + ts_lines[end]) / 2)

    for ix in range(len(text_lines)):
        start = ix
        end = ix + wsize if ix + wsize <= len(text_lines) else len(text_lines)
        windows.append(' '.join(text_lines[start:end]))
        timestamps.append((ts_lines[start] + ts_lines[end]) / 2)

    return windows, timestamps

# %%
def interp_lecture(lec_traj, timestamps):
    timestamps = np.array(timestamps) - timestamps[0]
    new_tpts = np.arange(timestamps[-1])
    interp_func = interp1d(timestamps, lec_traj, axis=0)
    return interp_func(new_tpts)

# %%
# def num2words(num):
#     if '^' in num:
#         base, power = num.split('^')
#         if power == '2':
#             exp_phrase = 'squared'
#         else:
#             exp_phrase = f'to the {num2words(power)}'
        
#         words = f'{num2words(base)} {exp_phrase}'
    
#     elif num.endswith('%'):
#         words = f'{num2words(num[:-1])} percent'
    
#     else:
#         num = num.replace(',', '')
#         if num.endswith(('st', 'nd', 'rd', 'th')):
#             num = num[:-2]
#             to = 'ordinal'
#         else:
#             to = 'cardinal'
        
#         words = _num2words(num, to=to).replace('-', ' ')
    
#     words = words.split()
#     while any(w in STOP_WORDS for w in words):
#         words.remove(next(w for w in words if w in STOP_WORDS))        

#     # remove puncutation & stop word automatically added by num2words
#     return ' '.join(words)

# %%
class parrotdict(dict):
    def __missing__(self, key):
        return key

# %%
def preprocess_text(textlist, custom_replacements=None, man_changes=None):
    if custom_replacements is None:
        custom_replacements = parrotdict()
    
    if man_changes is not None:
        assert isinstance(man_changes, defaultdict)

    # define some constants only used in this function:
    lemmatizer = WordNetLemmatizer()
    # suffixes to detect for manual lemmatization
    man_lemmatize_sfxs = ('s', 'ing', 'ly', 'ed', 'er', 'est')
    # mapping between Treebank and WordNet POS tags
    tagset_mapping = defaultdict(lambda: 'n')
    for tb_tag, wn_tag in zip(['N', 'P', 'V', 'J', 'D', 'R'],
                              ['n', 'n', 'v', 'a', 'a', 'r']):
        tagset_mapping[tb_tag] = wn_tag

    # insert delimiters between text samples to map processed text back
    # to original chunk
    chunk_delimiter = 'chunkdelimiter'
    processed_chunks = [[] for _ in textlist]
    # clean spacing, normalize case, strip puncutation
    # (temporarily leave punctuation useful for POS tagging)
    full_text = f' {chunk_delimiter} '.join(textlist).lower()
    punc_stripped = re.sub("[^a-zA-Z\s']+", '', full_text.replace('-', ' '))
    # POS tagging (works better on full transcript, more context provided)
    words_tags = pos_tag(punc_stripped.split())

    chunk_ix = 0
    for word, tag in words_tags:
        if word == chunk_delimiter:
            # denotes end of a text chunk
            chunk_ix += 1
            continue

        # discard contraction clitics (always stop words or possessive)
        # irregular stems (don, isn, etc.) handled by stop word removal
        elif "'" in word:
            word = word.split("'")[0]

        # remove stop words & digits
        if word in STOP_WORDS or word[0].isdigit():
            continue

        # convert Treebank POS tags to WordNet POS tags
        tag = tagset_mapping[tag[0]]
        # lemmatize
        lemma = lemmatizer.lemmatize(word, tag)
        
        lemma = custom_replacements[lemma]

        # handles most cases where POS tagger misidentifies a word, causing
        # WordNet Morphy to use the wrong syntactic transformation and fail
        if (
                lemma == word
                and any(word.endswith(sfx) for sfx in man_lemmatize_sfxs)
                and len(word) > 4
        ):
            lemma = synset_match(word)
            if lemma != word:
                if lemma in STOP_WORDS:
                    continue
                elif man_changes is not None:
                    # record changes made this way to spot-check later
                    man_changes[(word, lemma)] += 1

        elif lemma in STOP_WORDS:
            continue
        
        # place back in correct text chunk
        processed_chunks[chunk_ix].append(lemma)

    # join words within each chunk
    return [' '.join(c) for c in processed_chunks]

# %%
STOP_WORDS = stopwords.words('english') + ['also', 'bit', 
                                           'e', 'get', 'go', 'kind', 'let', 
                                           'like', 'mc2', 'really',
                                           'thing', 'us']

CUSTOM_REPLACEMENTS = {'electrom': 'electron'}
CUSTOM_REPLACEMENTS = parrotdict(**CUSTOM_REPLACEMENTS)

# %% [markdown]
# # END TEMPORARY CELLS

# %%
# from collections import Counter
# c = Counter()
# for i in lec_text_processed:
#     c[i]+= 1
    
# c.most_common()

# %% [markdown]
# ## Text replacements (for old transcripts)

# %%
# # forces
# # add "either" to stop words? kind (of)? kinda?
# """
# corks quarks 2:11 2:15
# electro magnetic electromagnetic 4.17 4.20 vs electromagnetic 5.07 5.29 5.32 etc
#     or maybe somehow make it match electromagnetism 4.14
# Ullom coulomb 5:16
# electro static electrostatic 6.09
# yes -> i guess 6.12
# cool coulomb 6.37
# will won't 7.00
# name named 7.12
# and it's -> in its 7.35
# sub nucleic -> subnucleic 8.47
# they the 9.28
# """

# # bos
# """
# Hugh huge 0.02
# instantly it's 0.21
# nucleus nucleuses 2.16
# force forces 2.24
# that -> is it 2.47
# out -> "ox--" 3.17 (started to say oxygen)
# nucleus nucleuses 3.28
# outward pressure to -> outward pressure to balance 4.25
# on in 4.44
# exhibit -> '' 4.51
# ours -> that happens in stars 4.55
# of -> i have 4.58
# and in 5.33
# of -> is the 6.36

# """

# %% [markdown]
# ## Define some functions

# %%
class ParamData:
    def __init__(self, n_topics, window_size, corpus_key):
        self.n_topics = n_topics
        self.window_size = window_size
        self.corpus_key = corpus_key
        
        self.forces_traj = None
        self.bos_traj = None
        self.forces_questions = None
        self.bos_questions = None
        self.gen_questions = None
        self.cv = None
        self.lda = None
        self.score = None
        
    def __repr__(self):
        params = f"(n_topics: {self.n_topics}, window_size: {self.window_size}, corpus_key: {self.corpus_key})"
        score = f"score: {self.score}"
        return f"{params}\n{score}"
    
    def __str__(self):
        return repr(self)
    
    def __eq__(self, other):
        return self.score == other.score
    
    def __ne__(self, other):
        return self.score != other.score
    
    def __gt__(self, other):
        return self.score > other.score
    
    def __ge__(self, other):
        return self.score >= other.score
    
    def __lt__(self, other):
        return self.score < other.score
    
    def __le__(self, other):
        return self.score <= other.score

    def fit_transform_data(self):
        forces_windows, forces_timestamps = parse_windows(ff_transcript_processed, 
                                                          self.window_size)
        bos_windows, bos_timestamps = parse_windows(bos_transcript_processed, 
                                                    self.window_size)
        forces_question_text = list(quiz_text_processed[:15, 0])
        bos_question_text = list(quiz_text_processed[15:30, 0])
        gen_question_text = list(quiz_text_processed[30:, 0])
        
        corpus = forces_windows + bos_windows + create_qa_corpus(self.corpus_key)
        self.cv = CountVectorizer(**CV_PARAMS)
        self.lda = LatentDirichletAllocation(n_components=self.n_topics, **LDA_PARAMS)
        self.lda.fit(self.cv.fit_transform(corpus))
        
        forces_traj = self.lda.transform(self.cv.transform(forces_windows))
        bos_traj = self.lda.transform(self.cv.transform(bos_windows))
        
        self.forces_traj = interp_lecture(forces_traj, forces_timestamps)
        self.bos_traj = interp_lecture(bos_traj, bos_timestamps)
        self.forces_questions = self.lda.transform(self.cv.transform(forces_question_text))
        self.bos_questions = self.lda.transform(self.cv.transform(bos_question_text))
        self.gen_questions = self.lda.transform(self.cv.transform(gen_question_text))

    def score_models(self):
        forces_score = self._score_single_lec(self.forces_traj, self.forces_questions)
        bos_score = self._score_single_lec(self.bos_traj, self.bos_questions)
        self.score = (forces_score + bos_score) / 2
        return self.score
        
    def _score_single_lec(self, lec_traj, questions):
        qq_corrmat = np.corrcoef(questions)
        qq_corrs = qq_corrmat[np.triu_indices_from(qq_corrmat, k=1)]
        
        lq_corrs = 1 - cdist(lec_traj, questions, 'correlation')
        max_tpts = lq_corrs.argmax(axis=0)
        max_tpt_distmat = np.abs(max_tpts[:, np.newaxis] - max_tpts)
        max_tpt_dists = max_tpt_distmat[np.triu_indices_from(max_tpt_distmat, k=1)]
        
        return -pearsonr(max_tpt_dists, qq_corrs)[0]
    
    def plot_topics(self, y_max=0.2):
        sns.set_style('ticks')
        fig, axarr = plt.subplots(2, 3)
        fig.set_size_inches(15, 10)
        axarr = axarr.flatten()

        for i, traj in enumerate([self.forces_traj, 
                                  self.bos_traj, 
                                  None, 
                                  self.forces_questions, 
                                  self.bos_questions, 
                                  self.gen_questions]):
            ax = axarr[i]
            if traj is None:
                ax.axis('off')
                continue

            topic_vars = np.var(traj, axis=0)
            bars = ax.bar(x=list(range(1, len(topic_vars)+1)), 
                          height=topic_vars, 
                          color=sns.color_palette('hls', len(topic_vars)))
            ax.set_ylim(0, y_max)
            ax.set_xlim(.5, len(topic_vars)+.5)
            ax.set_xticks(list(range(2, len(topic_vars)+1, 2)))
            if i == 0:
                ax.set_ylabel('Mean topic activation', fontsize='x-large')
                ax.set_title('Four Forces', fontsize='xx-large')
                ax.annotate('Lectures', xy=(-.5, .5), xycoords=ax.yaxis.label, 
                            size='xx-large', rotation=90, ha='right', va='center')
            elif i == 1:
                ax.set_title('Birth of Stars', fontsize='xx-large')
            elif i == 3:
                ax.set_ylabel('Mean topic activation', fontsize='x-large')
                ax.annotate('Questions', xy=(-.5, .5), xycoords=ax.yaxis.label, 
                            size='xx-large', rotation=90, ha='right', va='center')
            elif i == 5:
                ax.set_title('General Knowledge', fontsize='xx-large')
            if i > 2:
                ax.set_xlabel('Topic dimension', fontsize='x-large')
        plt.tight_layout()
        plt.show()
        
    def plot_heatmaps(self):
        plt.rcParams['pdf.fonttype'] = 42
        sns.set_context('paper')
        cmap = 'rocket'
        gridspec_kws = {
            'wspace': 0.1, 
            'hspace': 0.3, 
            'width_ratios': (1, 1, .3, 1)
        }
        cbar_kws = {'pad': 0.1}
        ff_traj = self.forces_traj
        bos_traj = self.bos_traj
        forces_qs = self.forces_questions
        bos_qs = self.bos_questions
        fig, axarr = plt.subplots(2, 4, gridspec_kw=gridspec_kws)
        fig.set_size_inches(12, 6)
        ((a, b, sep1, c), (d, e, sep2, f)) = axarr
        sns.heatmap(ff_traj, vmin=0, vmax=1, xticklabels=2, yticklabels=100, 
                    cbar=False, cmap=cmap, ax=a)
        a.collections[0].remove()
        aspect = ff_traj.shape[1] / ff_traj.shape[0]
        a.imshow(ff_traj, aspect=aspect, vmin=0, vmax=1, cmap=cmap)
        a.set_title('Lecture\ntopic proportions', fontsize=12)
        a.set_ylabel('Timepoint (s)', fontsize=12)
        a.annotate('Four Forces', xy=(-.75, .5), xycoords=a.yaxis.label, 
                   size='xx-large', rotation=90, ha='right', va='center')
        corrmat = np.corrcoef(ff_traj)
        sns.heatmap(corrmat, vmin=0, vmax=1, xticklabels=100, yticklabels=100, 
                    cbar=False, cmap=cmap, ax=b)
        b.collections[0].remove()
        b.imshow(corrmat, aspect='equal', vmin=0, vmax=1, cmap=cmap)
        b.set_title('Lecture\ncorrelation matrix', fontsize=12)
        sns.heatmap(forces_qs, vmin=0, vmax=1, xticklabels=2, yticklabels=2, 
                    cmap=cmap, cbar=True, cbar_kws=cbar_kws, ax=c)
        c.collections[0].remove()
        aspect = forces_qs.shape[1] / forces_qs.shape[0]
        c.imshow(forces_qs, aspect=aspect, vmin=0, vmax=1, cmap=cmap)
        c.set_yticklabels(list(range(1, 16, 2)), rotation=0)
        c.set_title('Question\ntopic proportions', fontsize=12)
        c.set_ylabel('Question', fontsize=12)
        sns.heatmap(bos_traj, vmin=0, vmax=1, xticklabels=2, yticklabels=100, 
                    cbar=False, cmap=cmap, ax=d)
        d.collections[0].remove()
        aspect = bos_traj.shape[1] / bos_traj.shape[0]
        d.imshow(bos_traj, aspect=aspect, vmin=0, vmax=1, cmap=cmap)
        d.set_xlabel('Topic', fontsize=12)
        d.set_ylabel('Timepoint (s)', fontsize=12)
        d.annotate('Birth of Stars', xy=(-.75, .5), xycoords=d.yaxis.label, 
                   size='xx-large', rotation=90, ha='right', va='center')
        corrmat = np.corrcoef(bos_traj)
        sns.heatmap(corrmat, vmin=0, vmax=1, xticklabels=100, yticklabels=100, 
                    cbar=False, cmap=cmap, ax=e)
        e.collections[0].remove()
        e.imshow(corrmat, aspect='equal', vmin=0, vmax=1, cmap=cmap)
        e.set_xlabel('Timepoint (s)', fontsize=12)
        sns.heatmap(bos_qs, vmin=0, vmax=1, xticklabels=2, yticklabels=2, 
                    cmap=cmap, cbar=True, cbar_kws=cbar_kws, ax=f)
        f.collections[0].remove()
        aspect = bos_qs.shape[1] / bos_qs.shape[0]
        f.imshow(bos_qs, aspect=aspect, vmin=0, vmax=1, cmap=cmap)
        f.set_yticklabels(list(range(16, 31, 2)), rotation=0)
        f.set_xlabel('Topic', fontsize=12)
        f.set_ylabel('Question', fontsize=12)
        xyA = (0, 1)
        xyB = (0, 0)
        vline = ConnectionPatch(xyA, xyB, coordsA='axes fraction', 
                                coordsB='axes fraction', axesA=sep1, axesB=sep2, 
                                linestyle='--', linewidth=1.5, color='grey')
        sep2.add_artist(vline)
        sep1.axis('off')
        sep2.axis('off')
        labels = 'ABCDEF'
        for i, ax in enumerate((a, b, c, d, e, f)):
            ax.text(-.1, 1.07, labels[i], horizontalalignment='center', 
                    transform=ax.transAxes, fontsize=12)
        plt.show()
        
    def plot_corr_timeseries(self):
        sns.set_context('talk')
        sns.set_palette(sns.hls_palette(15, h=.3))
        ff_traj = self.forces_traj
        bos_traj = self.bos_traj
        forces_qs = self.forces_questions
        bos_qs = self.bos_questions
        forces_qcorrs = 1 - cdist(ff_traj, forces_qs, 'correlation')
        bos_qcorrs = 1 - cdist(bos_traj, bos_qs, 'correlation')
        # choose some sample points to compare lecture & question content
        
        fig, axarr = plt.subplots(1, 2, sharey=True)
        fig.set_size_inches(20, 7)
        fax, bax = axarr
        fax.plot(forces_qcorrs)
        fax.set_xlim(0, ff_traj.shape[0])
        fax.set_ylim(-.2, 1.05)
        fax.set_xlabel('Lecture timepoint (s)')
        fax.set_ylabel('Topic vector correlation')
        fax.set_title('Four Forces', pad=20)
        fax.legend(labels=[f'Q {i}' for i in range(1, 16)], fontsize=12, loc=8, 
                   ncol=8, bbox_to_anchor=(.5, -.4))
        fax.grid(False)
        fax.text(0, 1.03, 'A', horizontalalignment='left', transform=fax.transAxes)
        bax.plot(bos_qcorrs)
        bax.set_xlim(0, bos_traj.shape[0])
        bax.set_ylim(-.2, 1.05)
        bax.set_xlabel('Lecture timepoint (s)')
        bax.set_title('Birth of Stars', pad=20)
        bax.legend(labels=[f'Q {i}' for i in range(16, 31)], fontsize=11.5, loc=8, 
                   ncol=8, bbox_to_anchor=(.5, -.4))
        bax.grid(False)
        bax.text(0, 1.03, 'B', horizontalalignment='left', transform=bax.transAxes)
        plt.subplots_adjust(wspace=-1)
        plt.tight_layout()
        plt.show()
    
    def plot_hypertools(self, ndims=3, reducer='IncrementalPCA', **hyp_kwargs):
        sns.reset_defaults()
        ff_traj = self.forces_traj
        bos_traj = self.bos_traj
        ff_qs_vecs = self.forces_questions
        bos_qs_vecs = self.bos_questions
        gen_qs_vecs = self.gen_questions
        fig, axarr = plt.subplots(3, 3, subplot_kw={'projection': '3d'}, gridspec_kw={'wspace': -.1, 'hspace': -.1})
        fig.set_size_inches(15, 10)
        axarr = axarr.flatten()
        for ax, azim in zip(axarr, range(0, 360, 45)):
            ax = hyp.plot([ff_traj, bos_traj, ff_qs_vecs, bos_qs_vecs, gen_qs_vecs], 
                          fmt=['r-', 'g-', 'bo', 'yo', 'ko'], 
                          ndims=ndims, 
                          reduce=reducer, 
                          azim=azim, 
                          show=False, 
                          ax=ax, **hyp_kwargs)
        axarr[-1].axis('off')
        fig.legend(['Four Forces lecture', 'Birth of Stars lecture', 
                    'Four Forces questions', 'Birth of Stars questions', 'general knowledge questions'],
                   loc='lower right', bbox_to_anchor=(.78, .09), fontsize='x-large')
        return fig
    
    def plot_qcorr_dists(self, n_bins=20, x_min=-1, x_max=1):
        forces_qcorrs = np.corrcoef(self.forces_questions)
        bos_qcorrs = np.corrcoef(self.bos_questions)
        plt.hist(forces_qcorrs[np.triu_indices_from(forces_qcorrs, k=1)], bins=n_bins)
        plt.xlim(x_min, x_max)
        plt.title('Four Forces')
        plt.show()
        plt.hist(bos_qcorrs[np.triu_indices_from(bos_qcorrs, k=1)], bins=n_bins)
        plt.xlim(x_min, x_max)
        plt.title('Birth of Stars')
        plt.show()

# %%
# def score_models_alt(pm):
#     ff_lec_vars = np.var(pm.forces_traj, axis=0)
#     ff_qs_vars = np.var(pm.forces_questions, axis=0)
#     bos_lec_vars = np.var(pm.bos_traj, axis=0)
#     bos_qs_vars = np.var(pm.bos_questions, axis=0)
    
#     ff_within = pearsonr(ff_lec_vars, ff_qs_vars)[0]
#     ff_across = pearsonr(ff_lec_vars, bos_qs_vars)[0]
    
#     bos_within = pearsonr(bos_lec_vars, bos_qs_vars)[0]
#     bos_across = pearsonr(bos_lec_vars, ff_qs_vars)[0]
    
#     ff_score = ff_within - ff_across
#     bos_score = bos_within - bos_across
    
#     return (ff_score + bos_score) / 2

# def score_models_alt(pm):
#     ff_lec_vars = np.var(pm.forces_traj, axis=0)
#     ff_qs_vars = np.var(pm.forces_questions, axis=0)
#     bos_lec_vars = np.var(pm.bos_traj, axis=0)
#     bos_qs_vars = np.var(pm.bos_questions, axis=0)
    
#     ff_within = (pearsonr(ff_lec_vars, ff_qs_vars)[0] + 1) / 2
#     ff_across = (pearsonr(ff_lec_vars, bos_qs_vars)[0] + 1) / 2
    
#     bos_within = (pearsonr(bos_lec_vars, bos_qs_vars)[0] + 1) / 2
#     bos_across = (pearsonr(bos_lec_vars, ff_qs_vars)[0] + 1) / 2
    
#     ff_ratio = ff_within / ff_across
#     bos_ratio = bos_within / bos_across
    
#     return (ff_ratio + bos_ratio) / 2

# %%
def score_models_alt(pm):
    if not hasattr(pm, 'answers') or pm.answers is None:
        ans = pm.lda.transform(pm.cv.transform(quiz_text_processed[:, 1:].ravel()))
        pm.answers = ans.reshape(39, 4, pm.n_topics)
    
    ff_score = _score_single_lec(pm.forces_traj, pm.forces_questions, pm.answers[:15, 0])
    bos_score = _score_single_lec(pm.bos_traj, pm.bos_questions, pm.answers[15:30, 0])
    return (ff_score + bos_score) / 2

def _score_single_lec(lec_traj, questions, correct_ans):
    lq_corrs =  1 - cdist(lec_traj, questions, 'correlation')
    la_corrs =  1 - cdist(lec_traj, correct_ans, 'correlation')
    max_q_tpts = lq_corrs.argmax(axis=0)
    max_a_tpts = la_corrs.argmax(axis=0)
    max_tpt_dists = np.abs(max_q_tpts - max_a_tpts)
    return max_tpt_dists.mean()

# %%
def create_qa_corpus(corpus_key):
    qa_corpus = []
    if 'Q' in corpus_key:
        # include all questions
        q_rows = quiz_text_processed[:]
    elif 'q' in corpus_key:
        # include lecture-related questions
        q_rows = quiz_text_processed[:30]
    else:
        # no questions (or answers) included
        return []
    
    qa_corpus.extend(q_rows[:, 0])
    if 'A' in corpus_key:
        # all answer choices
        qa_corpus.extend(q_rows[:, 1:].ravel())
    elif 'a' in corpus_key:
        # correct answers only
        qa_corpus.extend(q_rows[:, 1])
        
    return qa_corpus

# %%
def model_params(n_topics, window_size, corpus_key, objs_list):
    # if param combination has already been run, return object
    for obj in objs_list:
        if (obj.n_topics == n_topics and 
            obj.window_size == window_size and 
            obj.corpus_key == corpus_key):
            return obj
        
    new_obj = ParamData(n_topics, window_size, corpus_key)
    new_obj.fit_transform_data()
    try:
        new_obj.score_models()
    except:
        new_obj.score = 0
        print(new_obj)
        traceback.print_exc()
        
    objs_list.append(new_obj)
    return new_obj

# %%
def corpus_heatmap(x_dim, y_dim, max_val, **sns_kwargs):
    facet_data = sns_kwargs.pop('data')
    wide_data = facet_data.pivot(index=y_dim, columns=x_dim, values='score')
    ax = sns.heatmap(wide_data, **sns_kwargs)
    
    if (wide_data == max_val).any(axis=None):
        max_ix = np.unravel_index(wide_data.T.values.argmax(), wide_data.shape)
        rect = Rectangle(max_ix, 1, 1, fill=False, edgecolor='#FFF9AE', lw=3)
        ax.add_patch(rect)

# %%
def get_top_words(cv, lda, n_words=10):
    topic_words = {}
    vocab = cv.get_feature_names()
    for topic, component in enumerate(lda.components_):
        word_ix = np.argsort(component)[::-1][:n_words]
        topic_words[topic] = [vocab[i] for i in word_ix]
    return topic_words

# %% [markdown]
# ## Set static params

# %%
exp = Experiment()

# CountVectorizer params
CV_PARAMS = {
    'strip_accents': 'unicode',
    'stop_words': None,  # stop words already removed during preprocessing
}

# LatentDirichletAllocation params
LDA_PARAMS = {
    'learning_method': 'batch',
    'random_state': 0
}

# %% [markdown]
# ## Load participant data

# %%
PARTICIPANTS = []
raw_data = pd.read_csv(RAW_DIR.joinpath('psiturk-data-raw.tsv'), 
                       sep='\t', 
                       index_col='Unnamed: 0')
for ix, row in raw_data.iterrows():
    p = Participant.from_psiturk(row, subid=f"P{ix + 1}")
    PARTICIPANTS.append(p)

# %% [markdown]
# ## Preprocess lecture, question, and answer text

# %%
manual_changes = defaultdict(int)

ff_lines = exp.forces_transcript.splitlines()
ff_timestamps = ff_lines[::2]
ff_text_lines = ff_lines[1::2]
ff_lines_processed = preprocess_text(ff_text_lines, 
                                     custom_replacements=CUSTOM_REPLACEMENTS, 
                                     man_changes=manual_changes)

ff_transcript_processed = []
for ts_line, txt_line in zip(ff_timestamps, ff_lines_processed):
    ff_transcript_processed.append(f'{ts_line}\n{txt_line}')
ff_transcript_processed.append(ff_timestamps[-1])
ff_transcript_processed = '\n'.join(ff_transcript_processed)


bos_lines = exp.bos_transcript.splitlines()
bos_timestamps = bos_lines[::2]
bos_text_lines = bos_lines[1::2]
bos_lines_processed = preprocess_text(bos_text_lines, 
                                      custom_replacements=CUSTOM_REPLACEMENTS, 
                                      man_changes=manual_changes)

bos_transcript_processed = []
for ts_line, txt_line in zip(bos_timestamps, bos_lines_processed):
    bos_transcript_processed.append(f'{ts_line}\n{txt_line}')
bos_transcript_processed.append(bos_timestamps[-1])
bos_transcript_processed = '\n'.join(bos_transcript_processed)

# %%
quiz_text = exp.questions.values[:, 1:]
quiz_text_processed = preprocess_text(quiz_text.ravel(), 
                                      custom_replacements=CUSTOM_REPLACEMENTS, 
                                      man_changes=manual_changes)
quiz_text_processed = np.reshape(quiz_text_processed, quiz_text.shape)
question_text = quiz_text_processed[:, 0]

# %%
manual_changes
# Out:
# defaultdict(int,
#             {('actually', 'actual'): 23,
#              ('surprising', 'surprise'): 2,
#              ('exactly', 'exact'): 1,
#              ('essentially', 'essential'): 2,
#              ('completely', 'complete'): 1,
#              ('strongest', 'strong'): 1,
#              ('applies', 'apply'): 2,
#              ('disappears', 'disappear'): 1,
#              ('strongly', 'strong'): 1,
#              ('especially', 'specially'): 1,
#              ('slowly', 'slow'): 5,
#              ('denser', 'dense'): 6,
#              ('condensing', 'condense'): 2,
#              ('interesting', 'interest'): 1,
#              ('happens', 'happen'): 1,
#              ('obviously', 'obvious'): 2,
#              ('positively', 'positive'): 2,
#              ('slightly', 'slight'): 2,
#              ('degrades', 'degrade'): 1,
#              ('combined', 'combine'): 5,
#              ('eventually', 'eventual'): 2,
#              ('fused', 'fuse'): 1,
#              ('hydrogens', 'hydrogen'): 1,
#              ('following', 'follow'): 19,
#              ('collides', 'collide'): 1,
#              ('roughly', 'rough'): 2,
#              ('stronger', 'strong'): 2,
#              ('extremely', 'extreme'): 3,
#              ('relatively', 'relative'): 1,
#              ('negatively', 'negative'): 2,
#              ('explains', 'explain'): 1,
#              ('occurs', 'occur'): 2,
#              ('prevents', 'prevent'): 1,
#              ('accurately', 'accurate'): 1,
#              ('defines', 'define'): 1,
#              ('inflated', 'inflate'): 1})

# %% [markdown]
# ## Grid search params

# %%
# number of topics to fit the topic model
n_topics = [5, 10, 15, 20, 25, 30, 35]

# length of lecture transcript sliding window
lecture_wsize = [5, 10, 15, 20, 25, 30, 35]

# training corpus for topic model
# - l: lecture sliding windows
# - q: lecture-related multiple choice questions' text
# - Q: all multiple choice questions' text
# - a: correct responses to multiple choice questions
# - A: all options for responses to multiple choice questions
corpora = ['l', 'lq', 'lQ', 'lqa', 'lQa', 'lqA', 'lQA']

param_grid = [(t, w, c) for t in n_topics for w in lecture_wsize for c in corpora]

# %%
# PARAM_MODELS = []
# for params in tqdm(param_grid):
#     param_model = model_params(*params, objs_list=PARAM_MODELS)
#     print(param_model)

PARAM_MODELS = []
curr_best = None
for params in tqdm(param_grid):
    param_model = model_params(*params, objs_list=PARAM_MODELS)
    if curr_best is None or param_model > curr_best:
        print(param_model)
        curr_best = param_model
# Out:
# HBox(children=(IntProgress(value=0, max=343), HTML(value='')))
# (n_topics: 5, window_size: 5, corpus_key: l)
# score: 0.0852832755231375
# (n_topics: 5, window_size: 5, corpus_key: lq)
# score: 0.16587721045541448
# (n_topics: 5, window_size: 5, corpus_key: lQ)
# score: 0.18721255367369022
# (n_topics: 5, window_size: 5, corpus_key: lqa)
# score: 0.3662921619068233
# (n_topics: 5, window_size: 10, corpus_key: lQa)
# score: 0.3709927810453275
# (n_topics: 5, window_size: 15, corpus_key: lQ)
# score: 0.3807459653588387
# (n_topics: 5, window_size: 15, corpus_key: lQa)
# score: 0.5624871389852164
# (n_topics: 5, window_size: 35, corpus_key: lqa)
# score: 0.5768808407673512
# (n_topics: 5, window_size: 35, corpus_key: lqA)
# score: 0.5877621741440817
# (n_topics: 10, window_size: 30, corpus_key: lQ)
# score: 0.6339909838434689

# %%
# optimal number of topics, lecture window size, training corpus:
max(PARAM_MODELS)
# Out:
# (n_topics: 10, window_size: 30, corpus_key: lQ)
# score: 0.6339909838434689

# %%
np.array(PARAM_MODELS)[np.argsort(PARAM_MODELS)[::-1]]
# Out:
# array([(n_topics: 10, window_size: 30, corpus_key: lQ)
# score: 0.6339909838434689,
#        (n_topics: 10, window_size: 35, corpus_key: lQ)
# score: 0.6256934163534982,
#        (n_topics: 15, window_size: 30, corpus_key: lqa)
# score: 0.6085895755910457,
#        (n_topics: 5, window_size: 35, corpus_key: lqA)
# score: 0.5877621741440817,
#        (n_topics: 10, window_size: 30, corpus_key: lQa)
# score: 0.5845909155501774,
#        (n_topics: 10, window_size: 35, corpus_key: l)
# score: 0.5802175328474948,
#        (n_topics: 15, window_size: 20, corpus_key: lQa)
# score: 0.5784937219152584,
#        (n_topics: 5, window_size: 35, corpus_key: lqa)
# score: 0.5768808407673512,
#        (n_topics: 5, window_size: 15, corpus_key: lQa)
# score: 0.5624871389852164,
#        (n_topics: 5, window_size: 20, corpus_key: l)
# score: 0.5618820636797535,
#        (n_topics: 10, window_size: 30, corpus_key: l)
# score: 0.5569314407384443,
#        (n_topics: 15, window_size: 30, corpus_key: lQA)
# score: 0.554816834748127,
#        (n_topics: 10, window_size: 15, corpus_key: lqa)
# score: 0.55428834612371,
#        (n_topics: 5, window_size: 30, corpus_key: lqa)
# score: 0.5542293321012755,
#        (n_topics: 5, window_size: 30, corpus_key: l)
# score: 0.5425252537081753,
#        (n_topics: 10, window_size: 20, corpus_key: l)
# score: 0.5414536614891721,
#        (n_topics: 5, window_size: 20, corpus_key: lqa)
# score: 0.5398102118360344,
#        (n_topics: 5, window_size: 35, corpus_key: l)
# score: 0.5395996808064529,
#        (n_topics: 15, window_size: 15, corpus_key: lqa)
# score: 0.5297171798541549,
#        (n_topics: 5, window_size: 25, corpus_key: lqA)
# score: 0.5218863688196822,
#        (n_topics: 10, window_size: 30, corpus_key: lqa)
# score: 0.5212149701490044,
#        (n_topics: 10, window_size: 20, corpus_key: lqa)
# score: 0.519558772839688,
#        (n_topics: 15, window_size: 30, corpus_key: lQa)
# score: 0.5180496592852152,
#        (n_topics: 30, window_size: 5, corpus_key: lQ)
# score: 0.5180073839645174,
#        (n_topics: 15, window_size: 35, corpus_key: lqa)
# score: 0.5179557244626017,
#        (n_topics: 10, window_size: 30, corpus_key: lQA)
# score: 0.5157230858009155,
#        (n_topics: 15, window_size: 25, corpus_key: lQA)
# score: 0.5145569421188358,
#        (n_topics: 10, window_size: 25, corpus_key: lQ)
# score: 0.5132994882430094,
#        (n_topics: 5, window_size: 20, corpus_key: lQa)
# score: 0.5010021990111169,
#        (n_topics: 15, window_size: 10, corpus_key: lQa)
# score: 0.49425853306527245,
#        (n_topics: 10, window_size: 25, corpus_key: lQa)
# score: 0.4940398068976726,
#        (n_topics: 5, window_size: 30, corpus_key: lqA)
# score: 0.4919355122048848,
#        (n_topics: 15, window_size: 25, corpus_key: l)
# score: 0.4896316359916084,
#        (n_topics: 15, window_size: 30, corpus_key: l)
# score: 0.4892018866559884,
#        (n_topics: 15, window_size: 20, corpus_key: lQA)
# score: 0.4871230790089249,
#        (n_topics: 10, window_size: 30, corpus_key: lqA)
# score: 0.4855116634092362,
#        (n_topics: 10, window_size: 35, corpus_key: lQa)
# score: 0.48333862123325666,
#        (n_topics: 15, window_size: 15, corpus_key: lq)
# score: 0.48315837293439634,
#        (n_topics: 10, window_size: 15, corpus_key: lQa)
# score: 0.4812441847246146,
#        (n_topics: 5, window_size: 35, corpus_key: lQa)
# score: 0.48007584203059717,
#        (n_topics: 20, window_size: 35, corpus_key: lQa)
# score: 0.47941370036121,
#        (n_topics: 15, window_size: 25, corpus_key: lQa)
# score: 0.47765364906806695,
#        (n_topics: 15, window_size: 35, corpus_key: l)
# score: 0.47230237071804254,
#        (n_topics: 10, window_size: 20, corpus_key: lQa)
# score: 0.4717068880384615,
#        (n_topics: 15, window_size: 20, corpus_key: l)
# score: 0.4706830317183277,
#        (n_topics: 20, window_size: 5, corpus_key: l)
# score: 0.46960776043426145,
#        (n_topics: 10, window_size: 10, corpus_key: lq)
# score: 0.46855603344489183,
#        (n_topics: 20, window_size: 15, corpus_key: lqA)
# score: 0.4618598783504727,
#        (n_topics: 5, window_size: 25, corpus_key: lQa)
# score: 0.460250533341123,
#        (n_topics: 10, window_size: 35, corpus_key: lqA)
# score: 0.45839066089066516,
#        (n_topics: 20, window_size: 35, corpus_key: lQ)
# score: 0.45289168944166625,
#        (n_topics: 10, window_size: 20, corpus_key: lQ)
# score: 0.4522836895276525,
#        (n_topics: 35, window_size: 5, corpus_key: lQ)
# score: 0.4499070047108303,
#        (n_topics: 10, window_size: 25, corpus_key: lqA)
# score: 0.44822541222633205,
#        (n_topics: 35, window_size: 15, corpus_key: l)
# score: 0.4472050434530817,
#        (n_topics: 20, window_size: 20, corpus_key: l)
# score: 0.44589930620416085,
#        (n_topics: 25, window_size: 25, corpus_key: l)
# score: 0.4456862398572211,
#        (n_topics: 20, window_size: 25, corpus_key: l)
# score: 0.4422069674657505,
#        (n_topics: 30, window_size: 30, corpus_key: lqA)
# score: 0.44064962366474203,
#        (n_topics: 20, window_size: 30, corpus_key: lQa)
# score: 0.4402821598307289,
#        (n_topics: 5, window_size: 20, corpus_key: lq)
# score: 0.438900894570165,
#        (n_topics: 15, window_size: 10, corpus_key: l)
# score: 0.438167716972042,
#        (n_topics: 15, window_size: 35, corpus_key: lQa)
# score: 0.43698985705314264,
#        (n_topics: 15, window_size: 25, corpus_key: lqA)
# score: 0.43630858206210116,
#        (n_topics: 5, window_size: 35, corpus_key: lQ)
# score: 0.43474763469796596,
#        (n_topics: 15, window_size: 15, corpus_key: l)
# score: 0.4338507257303514,
#        (n_topics: 15, window_size: 35, corpus_key: lQ)
# score: 0.4334743605548823,
#        (n_topics: 15, window_size: 25, corpus_key: lqa)
# score: 0.4314981972438907,
#        (n_topics: 10, window_size: 25, corpus_key: lQA)
# score: 0.4280855822235293,
#        (n_topics: 15, window_size: 20, corpus_key: lqA)
# score: 0.42791345399089076,
#        (n_topics: 25, window_size: 20, corpus_key: lQ)
# score: 0.4245797631454944,
#        (n_topics: 20, window_size: 20, corpus_key: lQa)
# score: 0.4244724711724477,
#        (n_topics: 20, window_size: 35, corpus_key: lqa)
# score: 0.4242011322446114,
#        (n_topics: 25, window_size: 15, corpus_key: lQa)
# score: 0.42346305006338647,
#        (n_topics: 5, window_size: 25, corpus_key: lQ)
# score: 0.4209002718686544,
#        (n_topics: 25, window_size: 30, corpus_key: l)
# score: 0.41992871301927326,
#        (n_topics: 10, window_size: 15, corpus_key: l)
# score: 0.418781469106395,
#        (n_topics: 25, window_size: 25, corpus_key: lQA)
# score: 0.4157323738309038,
#        (n_topics: 10, window_size: 25, corpus_key: lq)
# score: 0.4153570329372199,
#        (n_topics: 20, window_size: 10, corpus_key: l)
# score: 0.4145587092486659,
#        (n_topics: 5, window_size: 20, corpus_key: lqA)
# score: 0.4132832766416379,
#        (n_topics: 25, window_size: 10, corpus_key: lqa)
# score: 0.410783276973965,
#        (n_topics: 30, window_size: 15, corpus_key: l)
# score: 0.41060593809097334,
#        (n_topics: 20, window_size: 5, corpus_key: lq)
# score: 0.40921178531619395,
#        (n_topics: 15, window_size: 20, corpus_key: lqa)
# score: 0.40821677832768116,
#        (n_topics: 20, window_size: 30, corpus_key: lQA)
# score: 0.40816412566957644,
#        (n_topics: 35, window_size: 10, corpus_key: lqa)
# score: 0.40764626011045935,
#        (n_topics: 10, window_size: 15, corpus_key: lqA)
# score: 0.40715404426628554,
#        (n_topics: 35, window_size: 10, corpus_key: lQ)
# score: 0.4048346201004732,
#        (n_topics: 35, window_size: 15, corpus_key: lQA)
# score: 0.4046750629299972,
#        (n_topics: 20, window_size: 10, corpus_key: lQa)
# score: 0.4022723768823041,
#        (n_topics: 10, window_size: 10, corpus_key: lQa)
# score: 0.4014043614152181,
#        (n_topics: 25, window_size: 10, corpus_key: lq)
# score: 0.3999959149810495,
#        (n_topics: 20, window_size: 5, corpus_key: lqa)
# score: 0.3988220855703054,
#        (n_topics: 15, window_size: 15, corpus_key: lQa)
# score: 0.39865124693747567,
#        (n_topics: 15, window_size: 15, corpus_key: lQA)
# score: 0.3975631743711543,
#        (n_topics: 25, window_size: 10, corpus_key: lQ)
# score: 0.3966216832645025,
#        (n_topics: 20, window_size: 15, corpus_key: lQa)
# score: 0.396211549467277,
#        (n_topics: 25, window_size: 15, corpus_key: lqA)
# score: 0.3953450119294623,
#        (n_topics: 35, window_size: 20, corpus_key: lQA)
# score: 0.3946390091162668,
#        (n_topics: 35, window_size: 15, corpus_key: lQ)
# score: 0.394028791659395,
#        (n_topics: 30, window_size: 10, corpus_key: l)
# score: 0.39326269291311905,
#        (n_topics: 20, window_size: 10, corpus_key: lq)
# score: 0.39255893062088765,
#        (n_topics: 35, window_size: 5, corpus_key: lqA)
# score: 0.39175310010336406,
#        (n_topics: 20, window_size: 25, corpus_key: lQa)
# score: 0.39169617396120143,
#        (n_topics: 5, window_size: 35, corpus_key: lq)
# score: 0.39076933086010246,
#        (n_topics: 5, window_size: 25, corpus_key: lqa)
# score: 0.38758532346600005,
#        (n_topics: 20, window_size: 10, corpus_key: lqA)
# score: 0.3857508156704115,
#        (n_topics: 25, window_size: 20, corpus_key: l)
# score: 0.385203403827057,
#        (n_topics: 15, window_size: 15, corpus_key: lqA)
# score: 0.3847206677175933,
#        (n_topics: 15, window_size: 30, corpus_key: lq)
# score: 0.3823487298302452,
#        (n_topics: 5, window_size: 15, corpus_key: lQ)
# score: 0.3807459653588387,
#        (n_topics: 35, window_size: 5, corpus_key: lq)
# score: 0.38024620693861944,
#        (n_topics: 30, window_size: 25, corpus_key: lQ)
# score: 0.37581299863177275,
#        (n_topics: 20, window_size: 35, corpus_key: l)
# score: 0.37491617728711013,
#        (n_topics: 10, window_size: 20, corpus_key: lqA)
# score: 0.3739807704710983,
#        (n_topics: 20, window_size: 15, corpus_key: l)
# score: 0.37362412609623763,
#        (n_topics: 5, window_size: 10, corpus_key: lQa)
# score: 0.3709927810453275,
#        (n_topics: 15, window_size: 35, corpus_key: lqA)
# score: 0.37078431382565624,
#        (n_topics: 35, window_size: 35, corpus_key: l)
# score: 0.3696475086437731,
#        (n_topics: 30, window_size: 10, corpus_key: lQ)
# score: 0.36809797631411806,
#        (n_topics: 35, window_size: 20, corpus_key: l)
# score: 0.367922920698886,
#        (n_topics: 5, window_size: 15, corpus_key: lqA)
# score: 0.3676164108400249,
#        (n_topics: 25, window_size: 10, corpus_key: lQa)
# score: 0.36722177734940825,
#        (n_topics: 5, window_size: 5, corpus_key: lqa)
# score: 0.3662921619068233,
#        (n_topics: 20, window_size: 30, corpus_key: lQ)
# score: 0.36532604347930087,
#        (n_topics: 5, window_size: 15, corpus_key: l)
# score: 0.3644197654090543,
#        (n_topics: 25, window_size: 35, corpus_key: l)
# score: 0.36371113785269726,
#        (n_topics: 20, window_size: 25, corpus_key: lq)
# score: 0.3627403714578344,
#        (n_topics: 15, window_size: 35, corpus_key: lQA)
# score: 0.36247255103723763,
#        (n_topics: 15, window_size: 10, corpus_key: lqa)
# score: 0.3616253735448738,
#        (n_topics: 20, window_size: 25, corpus_key: lQ)
# score: 0.3615590785236305,
#        (n_topics: 25, window_size: 35, corpus_key: lQ)
# score: 0.3614828225040181,
#        (n_topics: 30, window_size: 5, corpus_key: lq)
# score: 0.36131865867536406,
#        (n_topics: 30, window_size: 15, corpus_key: lqa)
# score: 0.36066853626757994,
#        (n_topics: 25, window_size: 15, corpus_key: lqa)
# score: 0.35891800724662837,
#        (n_topics: 10, window_size: 35, corpus_key: lq)
# score: 0.3580171917562496,
#        (n_topics: 5, window_size: 30, corpus_key: lQa)
# score: 0.3560624153402699,
#        (n_topics: 20, window_size: 30, corpus_key: l)
# score: 0.3547092812111119,
#        (n_topics: 20, window_size: 10, corpus_key: lQA)
# score: 0.354356919660863,
#        (n_topics: 25, window_size: 5, corpus_key: lQ)
# score: 0.35341628086671917,
#        (n_topics: 35, window_size: 10, corpus_key: lQa)
# score: 0.3521461748846891,
#        (n_topics: 5, window_size: 30, corpus_key: lQ)
# score: 0.3512762060207159,
#        (n_topics: 20, window_size: 30, corpus_key: lqa)
# score: 0.3512053858012563,
#        (n_topics: 30, window_size: 10, corpus_key: lqa)
# score: 0.3491416945976671,
#        (n_topics: 30, window_size: 5, corpus_key: lQA)
# score: 0.34696402654116043,
#        (n_topics: 20, window_size: 35, corpus_key: lQA)
# score: 0.3469162380728811,
#        (n_topics: 25, window_size: 20, corpus_key: lQa)
# score: 0.34645905859741827,
#        (n_topics: 5, window_size: 10, corpus_key: lqA)
# score: 0.3456217156231064,
#        (n_topics: 20, window_size: 10, corpus_key: lQ)
# score: 0.34379709685400206,
#        (n_topics: 35, window_size: 10, corpus_key: lq)
# score: 0.34271792012205277,
#        (n_topics: 20, window_size: 5, corpus_key: lQA)
# score: 0.34212898252334506,
#        (n_topics: 10, window_size: 25, corpus_key: l)
# score: 0.3397039977237335,
#        (n_topics: 35, window_size: 30, corpus_key: l)
# score: 0.339644963578954,
#        (n_topics: 15, window_size: 25, corpus_key: lQ)
# score: 0.3395447315020247,
#        (n_topics: 35, window_size: 25, corpus_key: l)
# score: 0.33917574699620734,
#        (n_topics: 10, window_size: 15, corpus_key: lQA)
# score: 0.3368751085295737,
#        (n_topics: 30, window_size: 35, corpus_key: lqa)
# score: 0.3354193541086514,
#        (n_topics: 10, window_size: 15, corpus_key: lQ)
# score: 0.33401891711787635,
#        (n_topics: 5, window_size: 25, corpus_key: lQA)
# score: 0.332145971207344,
#        (n_topics: 20, window_size: 35, corpus_key: lqA)
# score: 0.33185060650078624,
#        (n_topics: 5, window_size: 10, corpus_key: l)
# score: 0.3318501455019522,
#        (n_topics: 35, window_size: 20, corpus_key: lqa)
# score: 0.33032294837403386,
#        (n_topics: 25, window_size: 5, corpus_key: l)
# score: 0.32975980902606206,
#        (n_topics: 5, window_size: 20, corpus_key: lQ)
# score: 0.3292019897381879,
#        (n_topics: 15, window_size: 10, corpus_key: lQA)
# score: 0.3287988074131168,
#        (n_topics: 25, window_size: 10, corpus_key: l)
# score: 0.32862298611735496,
#        (n_topics: 20, window_size: 5, corpus_key: lqA)
# score: 0.32804896097012937,
#        (n_topics: 15, window_size: 35, corpus_key: lq)
# score: 0.3276340706709397,
#        (n_topics: 5, window_size: 30, corpus_key: lq)
# score: 0.327059428863851,
#        (n_topics: 20, window_size: 20, corpus_key: lqa)
# score: 0.3269574495553825,
#        (n_topics: 25, window_size: 25, corpus_key: lQ)
# score: 0.32635187863188714,
#        (n_topics: 30, window_size: 30, corpus_key: lQA)
# score: 0.3254306196346133,
#        (n_topics: 15, window_size: 5, corpus_key: lq)
# score: 0.32373456486728247,
#        (n_topics: 25, window_size: 5, corpus_key: lQA)
# score: 0.32311870117865055,
#        (n_topics: 15, window_size: 15, corpus_key: lQ)
# score: 0.3230125455780911,
#        (n_topics: 25, window_size: 15, corpus_key: lQA)
# score: 0.32296328204971686,
#        (n_topics: 30, window_size: 25, corpus_key: l)
# score: 0.32260875303053355,
#        (n_topics: 10, window_size: 30, corpus_key: lq)
# score: 0.3222373174665737,
#        (n_topics: 20, window_size: 15, corpus_key: lQ)
# score: 0.32137370133600107,
#        (n_topics: 25, window_size: 35, corpus_key: lQA)
# score: 0.3209125964354813,
#        (n_topics: 20, window_size: 15, corpus_key: lQA)
# score: 0.320898465556698,
#        (n_topics: 25, window_size: 20, corpus_key: lqA)
# score: 0.3204616539545059,
#        (n_topics: 30, window_size: 20, corpus_key: l)
# score: 0.320193140126139,
#        (n_topics: 35, window_size: 30, corpus_key: lQ)
# score: 0.31925178778948354,
#        (n_topics: 10, window_size: 20, corpus_key: lq)
# score: 0.3189425717712745,
#        (n_topics: 15, window_size: 5, corpus_key: lqa)
# score: 0.3182372585091643,
#        (n_topics: 10, window_size: 20, corpus_key: lQA)
# score: 0.31787815427605937,
#        (n_topics: 20, window_size: 20, corpus_key: lQA)
# score: 0.31774392589112577,
#        (n_topics: 20, window_size: 20, corpus_key: lq)
# score: 0.31691747417450306,
#        (n_topics: 30, window_size: 30, corpus_key: l)
# score: 0.31582395362342164,
#        (n_topics: 15, window_size: 10, corpus_key: lQ)
# score: 0.3153422132305598,
#        (n_topics: 35, window_size: 5, corpus_key: lQa)
# score: 0.3149103817404698,
#        (n_topics: 20, window_size: 5, corpus_key: lQa)
# score: 0.3147504380469453,
#        (n_topics: 25, window_size: 5, corpus_key: lq)
# score: 0.3114225810604069,
#        (n_topics: 30, window_size: 20, corpus_key: lq)
# score: 0.31076724910505893,
#        (n_topics: 15, window_size: 10, corpus_key: lqA)
# score: 0.3099702557985058,
#        (n_topics: 25, window_size: 5, corpus_key: lqa)
# score: 0.3088976328352856,
#        (n_topics: 30, window_size: 30, corpus_key: lQ)
# score: 0.30592317297208743,
#        (n_topics: 15, window_size: 10, corpus_key: lq)
# score: 0.3054541726265111,
#        (n_topics: 25, window_size: 15, corpus_key: l)
# score: 0.3046208197328123,
#        (n_topics: 25, window_size: 20, corpus_key: lqa)
# score: 0.30401919959060963,
#        (n_topics: 25, window_size: 30, corpus_key: lQ)
# score: 0.3023272759588832,
#        (n_topics: 25, window_size: 15, corpus_key: lQ)
# score: 0.30209140150241526,
#        (n_topics: 20, window_size: 15, corpus_key: lqa)
# score: 0.3020036253512071,
#        (n_topics: 25, window_size: 20, corpus_key: lQA)
# score: 0.30048275951881276,
#        (n_topics: 5, window_size: 25, corpus_key: lq)
# score: 0.3001243770205345,
#        (n_topics: 25, window_size: 5, corpus_key: lqA)
# score: 0.2994539549480715,
#        (n_topics: 15, window_size: 5, corpus_key: l)
# score: 0.29839218351694796,
#        (n_topics: 10, window_size: 35, corpus_key: lQA)
# score: 0.2983030780314555,
#        (n_topics: 25, window_size: 25, corpus_key: lqA)
# score: 0.29754749577969036,
#        (n_topics: 15, window_size: 30, corpus_key: lQ)
# score: 0.29331095774181376,
#        (n_topics: 5, window_size: 15, corpus_key: lq)
# score: 0.2929359027944578,
#        (n_topics: 30, window_size: 15, corpus_key: lQ)
# score: 0.29168109685084975,
#        (n_topics: 30, window_size: 35, corpus_key: l)
# score: 0.2913444029260115,
#        (n_topics: 30, window_size: 35, corpus_key: lQ)
# score: 0.2905765343096309,
#        (n_topics: 30, window_size: 15, corpus_key: lQA)
# score: 0.29030032846463133,
#        (n_topics: 35, window_size: 35, corpus_key: lq)
# score: 0.2900174536702688,
#        (n_topics: 30, window_size: 5, corpus_key: lqA)
# score: 0.28849582743245433,
#        (n_topics: 25, window_size: 10, corpus_key: lqA)
# score: 0.2871142055318179,
#        (n_topics: 20, window_size: 30, corpus_key: lq)
# score: 0.28698017709650536,
#        (n_topics: 10, window_size: 10, corpus_key: l)
# score: 0.2854797924827083,
#        (n_topics: 20, window_size: 5, corpus_key: lQ)
# score: 0.28541973678003957,
#        (n_topics: 25, window_size: 30, corpus_key: lQA)
# score: 0.2845096044155709,
#        (n_topics: 30, window_size: 30, corpus_key: lqa)
# score: 0.28334256611253134,
#        (n_topics: 10, window_size: 5, corpus_key: lqa)
# score: 0.2831732164096298,
#        (n_topics: 10, window_size: 10, corpus_key: lqA)
# score: 0.2826082332366694,
#        (n_topics: 35, window_size: 15, corpus_key: lq)
# score: 0.28123928178403057,
#        (n_topics: 25, window_size: 35, corpus_key: lqa)
# score: 0.27973863360383694,
#        (n_topics: 30, window_size: 35, corpus_key: lQa)
# score: 0.2780639712913972,
#        (n_topics: 5, window_size: 10, corpus_key: lQ)
# score: 0.2773238153075033,
#        (n_topics: 5, window_size: 35, corpus_key: lQA)
# score: 0.2768928224883126,
#        (n_topics: 35, window_size: 10, corpus_key: l)
# score: 0.2759816658545891,
#        (n_topics: 10, window_size: 35, corpus_key: lqa)
# score: 0.2688914376814642,
#        (n_topics: 15, window_size: 20, corpus_key: lQ)
# score: 0.26866962490072144,
#        (n_topics: 10, window_size: 5, corpus_key: l)
# score: 0.26843370843835546,
#        (n_topics: 5, window_size: 5, corpus_key: lqA)
# score: 0.26799925201923747,
#        (n_topics: 15, window_size: 5, corpus_key: lqA)
# score: 0.2657049437116859,
#        (n_topics: 5, window_size: 30, corpus_key: lQA)
# score: 0.26568737540637377,
#        (n_topics: 35, window_size: 25, corpus_key: lQa)
# score: 0.26450717760497544,
#        (n_topics: 15, window_size: 20, corpus_key: lq)
# score: 0.263221411083174,
#        (n_topics: 5, window_size: 10, corpus_key: lq)
# score: 0.26203280026919795,
#        (n_topics: 25, window_size: 30, corpus_key: lQa)
# score: 0.26088153099295597,
#        (n_topics: 25, window_size: 30, corpus_key: lqa)
# score: 0.258369579613312,
#        (n_topics: 20, window_size: 35, corpus_key: lq)
# score: 0.25802244754328274,
#        (n_topics: 30, window_size: 30, corpus_key: lQa)
# score: 0.25751125441612477,
#        (n_topics: 30, window_size: 35, corpus_key: lq)
# score: 0.25653893830661684,
#        (n_topics: 30, window_size: 20, corpus_key: lQ)
# score: 0.2564525902515878,
#        (n_topics: 10, window_size: 10, corpus_key: lqa)
# score: 0.25557497735570867,
#        (n_topics: 15, window_size: 25, corpus_key: lq)
# score: 0.25065100076373975,
#        (n_topics: 35, window_size: 5, corpus_key: l)
# score: 0.2503406563272811,
#        (n_topics: 35, window_size: 20, corpus_key: lqA)
# score: 0.2500454496129347,
#        (n_topics: 30, window_size: 20, corpus_key: lqa)
# score: 0.2499854426126938,
#        (n_topics: 25, window_size: 35, corpus_key: lq)
# score: 0.24826093786057726,
#        (n_topics: 30, window_size: 5, corpus_key: lQa)
# score: 0.2479250499677076,
#        (n_topics: 20, window_size: 25, corpus_key: lQA)
# score: 0.2452982075359818,
#        (n_topics: 10, window_size: 15, corpus_key: lq)
# score: 0.24358571037163668,
#        (n_topics: 10, window_size: 5, corpus_key: lqA)
# score: 0.24352884570167768,
#        (n_topics: 35, window_size: 25, corpus_key: lqA)
# score: 0.24275793350232291,
#        (n_topics: 5, window_size: 15, corpus_key: lqa)
# score: 0.24274149923733584,
#        (n_topics: 30, window_size: 25, corpus_key: lq)
# score: 0.242530041176644,
#        (n_topics: 25, window_size: 30, corpus_key: lq)
# score: 0.2419140367424588,
#        (n_topics: 35, window_size: 35, corpus_key: lQ)
# score: 0.2418568735858055,
#        (n_topics: 15, window_size: 30, corpus_key: lqA)
# score: 0.24147525742957232,
#        (n_topics: 20, window_size: 20, corpus_key: lqA)
# score: 0.23861785159060356,
#        (n_topics: 35, window_size: 25, corpus_key: lqa)
# score: 0.236161335055957,
#        (n_topics: 35, window_size: 25, corpus_key: lQ)
# score: 0.23417611379776027,
#        (n_topics: 25, window_size: 25, corpus_key: lq)
# score: 0.2300547279515161,
#        (n_topics: 30, window_size: 20, corpus_key: lQA)
# score: 0.23004369562231497,
#        (n_topics: 15, window_size: 5, corpus_key: lQ)
# score: 0.22960366382670017,
#        (n_topics: 20, window_size: 25, corpus_key: lqA)
# score: 0.22854434623972392,
#        (n_topics: 5, window_size: 25, corpus_key: l)
# score: 0.22820786528814369,
#        (n_topics: 25, window_size: 25, corpus_key: lQa)
# score: 0.22814321229101103,
#        (n_topics: 25, window_size: 15, corpus_key: lq)
# score: 0.22632600283886223,
#        (n_topics: 30, window_size: 35, corpus_key: lQA)
# score: 0.22447748074141846,
#        (n_topics: 25, window_size: 25, corpus_key: lqa)
# score: 0.22120298823311918,
#        (n_topics: 30, window_size: 15, corpus_key: lq)
# score: 0.21846195809384078,
#        (n_topics: 35, window_size: 35, corpus_key: lqa)
# score: 0.21739431943493254,
#        (n_topics: 20, window_size: 30, corpus_key: lqA)
# score: 0.21682338920265498,
#        (n_topics: 35, window_size: 30, corpus_key: lq)
# score: 0.21344643057444132,
#        (n_topics: 25, window_size: 5, corpus_key: lQa)
# score: 0.2121045153199196,
#        (n_topics: 25, window_size: 20, corpus_key: lq)
# score: 0.21200262957466837,
#        (n_topics: 35, window_size: 10, corpus_key: lQA)
# score: 0.2103587975829575,
#        (n_topics: 30, window_size: 20, corpus_key: lQa)
# score: 0.2097719634369022,
#        (n_topics: 30, window_size: 15, corpus_key: lQa)
# score: 0.20722749931060014,
#        (n_topics: 30, window_size: 10, corpus_key: lQA)
# score: 0.2054772527762393,
#        (n_topics: 20, window_size: 10, corpus_key: lqa)
# score: 0.20501165959970927,
#        (n_topics: 35, window_size: 35, corpus_key: lQa)
# score: 0.2029600141540997,
#        (n_topics: 30, window_size: 25, corpus_key: lqa)
# score: 0.20262266950439745,
#        (n_topics: 10, window_size: 25, corpus_key: lqa)
# score: 0.2022953417116659,
#        (n_topics: 30, window_size: 5, corpus_key: l)
# score: 0.2013768439027953,
#        (n_topics: 15, window_size: 5, corpus_key: lQA)
# score: 0.200827519042241,
#        (n_topics: 30, window_size: 10, corpus_key: lqA)
# score: 0.19498025897400073,
#        (n_topics: 35, window_size: 15, corpus_key: lqA)
# score: 0.19452149877120248,
#        (n_topics: 35, window_size: 30, corpus_key: lQa)
# score: 0.19429862676531595,
#        (n_topics: 5, window_size: 5, corpus_key: lQ)
# score: 0.18721255367369022,
#        (n_topics: 30, window_size: 25, corpus_key: lQA)
# score: 0.18643850939060094,
#        (n_topics: 35, window_size: 5, corpus_key: lQA)
# score: 0.18616290815162595,
#        (n_topics: 30, window_size: 25, corpus_key: lQa)
# score: 0.18439796859101232,
#        (n_topics: 35, window_size: 35, corpus_key: lqA)
# score: 0.18195013822794895,
#        (n_topics: 35, window_size: 15, corpus_key: lQa)
# score: 0.17913747202510444,
#        (n_topics: 35, window_size: 30, corpus_key: lQA)
# score: 0.1773943475161749,
#        (n_topics: 20, window_size: 25, corpus_key: lqa)
# score: 0.17697362661166402,
#        (n_topics: 35, window_size: 5, corpus_key: lqa)
# score: 0.17275993840608728,
#        (n_topics: 15, window_size: 5, corpus_key: lQa)
# score: 0.16824864884760293,
#        (n_topics: 20, window_size: 15, corpus_key: lq)
# score: 0.16660618194327007,
#        (n_topics: 5, window_size: 5, corpus_key: lq)
# score: 0.16587721045541448,
#        (n_topics: 10, window_size: 5, corpus_key: lq)
# score: 0.1649783452902349,
#        (n_topics: 35, window_size: 15, corpus_key: lqa)
# score: 0.16080745209932135,
#        (n_topics: 5, window_size: 15, corpus_key: lQA)
# score: 0.15828762531271162,
#        (n_topics: 35, window_size: 30, corpus_key: lqa)
# score: 0.15052138599803863,
#        (n_topics: 5, window_size: 20, corpus_key: lQA)
# score: 0.14516000979693838,
#        (n_topics: 25, window_size: 10, corpus_key: lQA)
# score: 0.14498513724919854,
#        (n_topics: 30, window_size: 15, corpus_key: lqA)
# score: 0.1387789734087814,
#        (n_topics: 25, window_size: 35, corpus_key: lqA)
# score: 0.1356368854815504,
#        (n_topics: 35, window_size: 30, corpus_key: lqA)
# score: 0.13076589207441436,
#        (n_topics: 10, window_size: 10, corpus_key: lQA)
# score: 0.13069117516076043,
#        (n_topics: 35, window_size: 25, corpus_key: lq)
# score: 0.12913667763674183,
#        (n_topics: 30, window_size: 10, corpus_key: lq)
# score: 0.1240423579937297,
#        (n_topics: 30, window_size: 30, corpus_key: lq)
# score: 0.12154572092194488,
#        (n_topics: 35, window_size: 25, corpus_key: lQA)
# score: 0.11638422936473741,
#        (n_topics: 10, window_size: 5, corpus_key: lQa)
# score: 0.11544512186727364,
#        (n_topics: 30, window_size: 25, corpus_key: lqA)
# score: 0.11323729110276097,
#        (n_topics: 20, window_size: 20, corpus_key: lQ)
# score: 0.11284668351083937,
#        (n_topics: 35, window_size: 20, corpus_key: lQa)
# score: 0.10622548459051985,
#        (n_topics: 35, window_size: 10, corpus_key: lqA)
# score: 0.10409871713185175,
#        (n_topics: 25, window_size: 30, corpus_key: lqA)
# score: 0.09888449179629405,
#        (n_topics: 10, window_size: 5, corpus_key: lQA)
# score: 0.09780176766581647,
#        (n_topics: 30, window_size: 35, corpus_key: lqA)
# score: 0.09428632058089119,
#        (n_topics: 25, window_size: 35, corpus_key: lQa)
# score: 0.09370365267672229,
#        (n_topics: 30, window_size: 10, corpus_key: lQa)
# score: 0.09190727283896272,
#        (n_topics: 30, window_size: 20, corpus_key: lqA)
# score: 0.0917844995001183,
#        (n_topics: 30, window_size: 5, corpus_key: lqa)
# score: 0.09171357287081265,
#        (n_topics: 35, window_size: 20, corpus_key: lq)
# score: 0.08738832258866935,
#        (n_topics: 35, window_size: 20, corpus_key: lQ)
# score: 0.08640954056662561,
#        (n_topics: 5, window_size: 5, corpus_key: l)
# score: 0.0852832755231375,
#        (n_topics: 10, window_size: 5, corpus_key: lQ)
# score: 0.084323911523715,
#        (n_topics: 5, window_size: 10, corpus_key: lqa)
# score: 0.07896879875042759,
#        (n_topics: 35, window_size: 35, corpus_key: lQA)
# score: 0.07849933152217939,
#        (n_topics: 10, window_size: 10, corpus_key: lQ)
# score: 0.07428506954035569,
#        (n_topics: 5, window_size: 5, corpus_key: lQA)
# score: 0.06706540375217979,
#        (n_topics: 5, window_size: 10, corpus_key: lQA)
# score: 0.035638797663521196,
#        (n_topics: 5, window_size: 5, corpus_key: lQa)
# score: 0.016461170155030645], dtype=object)

# %%
alt_scores = []
for pm in PARAM_MODELS:
    alt_score = score_models_alt(pm)
    alt_scores.append(alt_score)

# %%
np.array(PARAM_MODELS)[np.argsort(alt_scores)]
# Out:
# array([(n_topics: 20, window_size: 20, corpus_key: lqA)
# score: 0.23861785159060356,
#        (n_topics: 25, window_size: 20, corpus_key: lQA)
# score: 0.30048275951881276,
#        (n_topics: 25, window_size: 5, corpus_key: lq)
# score: 0.3114225810604069,
#        (n_topics: 35, window_size: 25, corpus_key: l)
# score: 0.33917574699620734,
#        (n_topics: 15, window_size: 20, corpus_key: lQA)
# score: 0.4871230790089249,
#        (n_topics: 20, window_size: 25, corpus_key: lqa)
# score: 0.17697362661166402,
#        (n_topics: 15, window_size: 35, corpus_key: lQa)
# score: 0.43698985705314264,
#        (n_topics: 25, window_size: 25, corpus_key: lQa)
# score: 0.22814321229101103,
#        (n_topics: 35, window_size: 20, corpus_key: l)
# score: 0.367922920698886,
#        (n_topics: 10, window_size: 30, corpus_key: lQa)
# score: 0.5845909155501774,
#        (n_topics: 5, window_size: 5, corpus_key: lQa)
# score: 0.016461170155030645,
#        (n_topics: 30, window_size: 20, corpus_key: lqA)
# score: 0.0917844995001183,
#        (n_topics: 20, window_size: 20, corpus_key: lQa)
# score: 0.4244724711724477,
#        (n_topics: 20, window_size: 15, corpus_key: lq)
# score: 0.16660618194327007,
#        (n_topics: 20, window_size: 35, corpus_key: lQ)
# score: 0.45289168944166625,
#        (n_topics: 15, window_size: 25, corpus_key: lQA)
# score: 0.5145569421188358,
#        (n_topics: 20, window_size: 20, corpus_key: lqa)
# score: 0.3269574495553825,
#        (n_topics: 30, window_size: 25, corpus_key: lQa)
# score: 0.18439796859101232,
#        (n_topics: 30, window_size: 30, corpus_key: l)
# score: 0.31582395362342164,
#        (n_topics: 25, window_size: 20, corpus_key: lQ)
# score: 0.4245797631454944,
#        (n_topics: 35, window_size: 10, corpus_key: lqa)
# score: 0.40764626011045935,
#        (n_topics: 30, window_size: 20, corpus_key: lQ)
# score: 0.2564525902515878,
#        (n_topics: 35, window_size: 35, corpus_key: lq)
# score: 0.2900174536702688,
#        (n_topics: 25, window_size: 15, corpus_key: l)
# score: 0.3046208197328123,
#        (n_topics: 35, window_size: 10, corpus_key: lQa)
# score: 0.3521461748846891,
#        (n_topics: 20, window_size: 15, corpus_key: lQ)
# score: 0.32137370133600107,
#        (n_topics: 35, window_size: 35, corpus_key: lQa)
# score: 0.2029600141540997,
#        (n_topics: 30, window_size: 35, corpus_key: l)
# score: 0.2913444029260115,
#        (n_topics: 10, window_size: 25, corpus_key: l)
# score: 0.3397039977237335,
#        (n_topics: 15, window_size: 15, corpus_key: lQa)
# score: 0.39865124693747567,
#        (n_topics: 35, window_size: 20, corpus_key: lQA)
# score: 0.3946390091162668,
#        (n_topics: 30, window_size: 15, corpus_key: lqa)
# score: 0.36066853626757994,
#        (n_topics: 30, window_size: 25, corpus_key: lqA)
# score: 0.11323729110276097,
#        (n_topics: 20, window_size: 30, corpus_key: lq)
# score: 0.28698017709650536,
#        (n_topics: 30, window_size: 15, corpus_key: l)
# score: 0.41060593809097334,
#        (n_topics: 15, window_size: 30, corpus_key: lQA)
# score: 0.554816834748127,
#        (n_topics: 10, window_size: 25, corpus_key: lQa)
# score: 0.4940398068976726,
#        (n_topics: 15, window_size: 15, corpus_key: lqA)
# score: 0.3847206677175933,
#        (n_topics: 20, window_size: 20, corpus_key: lq)
# score: 0.31691747417450306,
#        (n_topics: 20, window_size: 25, corpus_key: l)
# score: 0.4422069674657505,
#        (n_topics: 20, window_size: 35, corpus_key: l)
# score: 0.37491617728711013,
#        (n_topics: 20, window_size: 25, corpus_key: lqA)
# score: 0.22854434623972392,
#        (n_topics: 25, window_size: 35, corpus_key: l)
# score: 0.36371113785269726,
#        (n_topics: 15, window_size: 25, corpus_key: lQa)
# score: 0.47765364906806695,
#        (n_topics: 25, window_size: 25, corpus_key: lqA)
# score: 0.29754749577969036,
#        (n_topics: 35, window_size: 20, corpus_key: lqa)
# score: 0.33032294837403386,
#        (n_topics: 15, window_size: 30, corpus_key: lqA)
# score: 0.24147525742957232,
#        (n_topics: 25, window_size: 30, corpus_key: lQ)
# score: 0.3023272759588832,
#        (n_topics: 20, window_size: 30, corpus_key: l)
# score: 0.3547092812111119,
#        (n_topics: 30, window_size: 10, corpus_key: lqA)
# score: 0.19498025897400073,
#        (n_topics: 30, window_size: 10, corpus_key: l)
# score: 0.39326269291311905,
#        (n_topics: 30, window_size: 15, corpus_key: lQ)
# score: 0.29168109685084975,
#        (n_topics: 30, window_size: 30, corpus_key: lQ)
# score: 0.30592317297208743,
#        (n_topics: 20, window_size: 10, corpus_key: l)
# score: 0.4145587092486659,
#        (n_topics: 25, window_size: 15, corpus_key: lqA)
# score: 0.3953450119294623,
#        (n_topics: 20, window_size: 30, corpus_key: lQa)
# score: 0.4402821598307289,
#        (n_topics: 35, window_size: 30, corpus_key: lq)
# score: 0.21344643057444132,
#        (n_topics: 35, window_size: 30, corpus_key: l)
# score: 0.339644963578954,
#        (n_topics: 30, window_size: 15, corpus_key: lqA)
# score: 0.1387789734087814,
#        (n_topics: 25, window_size: 15, corpus_key: lq)
# score: 0.22632600283886223,
#        (n_topics: 20, window_size: 35, corpus_key: lQA)
# score: 0.3469162380728811,
#        (n_topics: 35, window_size: 35, corpus_key: l)
# score: 0.3696475086437731,
#        (n_topics: 35, window_size: 10, corpus_key: lqA)
# score: 0.10409871713185175,
#        (n_topics: 20, window_size: 30, corpus_key: lqa)
# score: 0.3512053858012563,
#        (n_topics: 20, window_size: 20, corpus_key: lQA)
# score: 0.31774392589112577,
#        (n_topics: 35, window_size: 5, corpus_key: l)
# score: 0.2503406563272811,
#        (n_topics: 25, window_size: 25, corpus_key: lq)
# score: 0.2300547279515161,
#        (n_topics: 35, window_size: 5, corpus_key: lqA)
# score: 0.39175310010336406,
#        (n_topics: 10, window_size: 35, corpus_key: l)
# score: 0.5802175328474948,
#        (n_topics: 30, window_size: 10, corpus_key: lqa)
# score: 0.3491416945976671,
#        (n_topics: 30, window_size: 30, corpus_key: lq)
# score: 0.12154572092194488,
#        (n_topics: 15, window_size: 25, corpus_key: l)
# score: 0.4896316359916084,
#        (n_topics: 15, window_size: 25, corpus_key: lq)
# score: 0.25065100076373975,
#        (n_topics: 10, window_size: 30, corpus_key: l)
# score: 0.5569314407384443,
#        (n_topics: 20, window_size: 35, corpus_key: lQa)
# score: 0.47941370036121,
#        (n_topics: 35, window_size: 15, corpus_key: lqA)
# score: 0.19452149877120248,
#        (n_topics: 20, window_size: 25, corpus_key: lq)
# score: 0.3627403714578344,
#        (n_topics: 20, window_size: 15, corpus_key: l)
# score: 0.37362412609623763,
#        (n_topics: 30, window_size: 20, corpus_key: l)
# score: 0.320193140126139,
#        (n_topics: 25, window_size: 20, corpus_key: l)
# score: 0.385203403827057,
#        (n_topics: 15, window_size: 25, corpus_key: lqA)
# score: 0.43630858206210116,
#        (n_topics: 30, window_size: 25, corpus_key: lqa)
# score: 0.20262266950439745,
#        (n_topics: 15, window_size: 5, corpus_key: l)
# score: 0.29839218351694796,
#        (n_topics: 20, window_size: 30, corpus_key: lQA)
# score: 0.40816412566957644,
#        (n_topics: 25, window_size: 10, corpus_key: lq)
# score: 0.3999959149810495,
#        (n_topics: 25, window_size: 30, corpus_key: l)
# score: 0.41992871301927326,
#        (n_topics: 15, window_size: 15, corpus_key: lQA)
# score: 0.3975631743711543,
#        (n_topics: 20, window_size: 35, corpus_key: lqA)
# score: 0.33185060650078624,
#        (n_topics: 10, window_size: 35, corpus_key: lqa)
# score: 0.2688914376814642,
#        (n_topics: 15, window_size: 25, corpus_key: lQ)
# score: 0.3395447315020247,
#        (n_topics: 20, window_size: 15, corpus_key: lqA)
# score: 0.4618598783504727,
#        (n_topics: 25, window_size: 35, corpus_key: lQA)
# score: 0.3209125964354813,
#        (n_topics: 15, window_size: 20, corpus_key: l)
# score: 0.4706830317183277,
#        (n_topics: 25, window_size: 35, corpus_key: lq)
# score: 0.24826093786057726,
#        (n_topics: 15, window_size: 10, corpus_key: lq)
# score: 0.3054541726265111,
#        (n_topics: 30, window_size: 30, corpus_key: lqA)
# score: 0.44064962366474203,
#        (n_topics: 25, window_size: 20, corpus_key: lqa)
# score: 0.30401919959060963,
#        (n_topics: 30, window_size: 20, corpus_key: lq)
# score: 0.31076724910505893,
#        (n_topics: 25, window_size: 25, corpus_key: l)
# score: 0.4456862398572211,
#        (n_topics: 15, window_size: 15, corpus_key: l)
# score: 0.4338507257303514,
#        (n_topics: 35, window_size: 15, corpus_key: l)
# score: 0.4472050434530817,
#        (n_topics: 15, window_size: 30, corpus_key: lqa)
# score: 0.6085895755910457,
#        (n_topics: 30, window_size: 25, corpus_key: l)
# score: 0.32260875303053355,
#        (n_topics: 25, window_size: 5, corpus_key: lQA)
# score: 0.32311870117865055,
#        (n_topics: 25, window_size: 30, corpus_key: lq)
# score: 0.2419140367424588,
#        (n_topics: 35, window_size: 10, corpus_key: lQ)
# score: 0.4048346201004732,
#        (n_topics: 20, window_size: 35, corpus_key: lq)
# score: 0.25802244754328274,
#        (n_topics: 20, window_size: 25, corpus_key: lQa)
# score: 0.39169617396120143,
#        (n_topics: 15, window_size: 20, corpus_key: lqa)
# score: 0.40821677832768116,
#        (n_topics: 35, window_size: 15, corpus_key: lQa)
# score: 0.17913747202510444,
#        (n_topics: 20, window_size: 5, corpus_key: lq)
# score: 0.40921178531619395,
#        (n_topics: 25, window_size: 10, corpus_key: l)
# score: 0.32862298611735496,
#        (n_topics: 30, window_size: 5, corpus_key: lQA)
# score: 0.34696402654116043,
#        (n_topics: 25, window_size: 35, corpus_key: lqA)
# score: 0.1356368854815504,
#        (n_topics: 15, window_size: 20, corpus_key: lQa)
# score: 0.5784937219152584,
#        (n_topics: 20, window_size: 10, corpus_key: lq)
# score: 0.39255893062088765,
#        (n_topics: 35, window_size: 5, corpus_key: lQA)
# score: 0.18616290815162595,
#        (n_topics: 5, window_size: 15, corpus_key: lqA)
# score: 0.3676164108400249,
#        (n_topics: 25, window_size: 35, corpus_key: lqa)
# score: 0.27973863360383694,
#        (n_topics: 25, window_size: 20, corpus_key: lqA)
# score: 0.3204616539545059,
#        (n_topics: 5, window_size: 20, corpus_key: l)
# score: 0.5618820636797535,
#        (n_topics: 25, window_size: 15, corpus_key: lQA)
# score: 0.32296328204971686,
#        (n_topics: 30, window_size: 10, corpus_key: lq)
# score: 0.1240423579937297,
#        (n_topics: 35, window_size: 15, corpus_key: lQ)
# score: 0.394028791659395,
#        (n_topics: 15, window_size: 20, corpus_key: lqA)
# score: 0.42791345399089076,
#        (n_topics: 35, window_size: 10, corpus_key: lq)
# score: 0.34271792012205277,
#        (n_topics: 5, window_size: 35, corpus_key: l)
# score: 0.5395996808064529,
#        (n_topics: 30, window_size: 20, corpus_key: lQA)
# score: 0.23004369562231497,
#        (n_topics: 10, window_size: 10, corpus_key: l)
# score: 0.2854797924827083,
#        (n_topics: 5, window_size: 20, corpus_key: lQa)
# score: 0.5010021990111169,
#        (n_topics: 15, window_size: 35, corpus_key: lQA)
# score: 0.36247255103723763,
#        (n_topics: 30, window_size: 30, corpus_key: lQa)
# score: 0.25751125441612477,
#        (n_topics: 15, window_size: 15, corpus_key: lQ)
# score: 0.3230125455780911,
#        (n_topics: 15, window_size: 35, corpus_key: lqa)
# score: 0.5179557244626017,
#        (n_topics: 5, window_size: 20, corpus_key: lqA)
# score: 0.4132832766416379,
#        (n_topics: 30, window_size: 15, corpus_key: lq)
# score: 0.21846195809384078,
#        (n_topics: 20, window_size: 5, corpus_key: lQA)
# score: 0.34212898252334506,
#        (n_topics: 5, window_size: 10, corpus_key: lQ)
# score: 0.2773238153075033,
#        (n_topics: 5, window_size: 15, corpus_key: lQ)
# score: 0.3807459653588387,
#        (n_topics: 10, window_size: 20, corpus_key: l)
# score: 0.5414536614891721,
#        (n_topics: 15, window_size: 30, corpus_key: l)
# score: 0.4892018866559884,
#        (n_topics: 15, window_size: 30, corpus_key: lQa)
# score: 0.5180496592852152,
#        (n_topics: 35, window_size: 5, corpus_key: lq)
# score: 0.38024620693861944,
#        (n_topics: 15, window_size: 35, corpus_key: l)
# score: 0.47230237071804254,
#        (n_topics: 25, window_size: 35, corpus_key: lQa)
# score: 0.09370365267672229,
#        (n_topics: 35, window_size: 25, corpus_key: lqa)
# score: 0.236161335055957,
#        (n_topics: 20, window_size: 10, corpus_key: lQa)
# score: 0.4022723768823041,
#        (n_topics: 10, window_size: 20, corpus_key: lQA)
# score: 0.31787815427605937,
#        (n_topics: 20, window_size: 25, corpus_key: lQA)
# score: 0.2452982075359818,
#        (n_topics: 25, window_size: 10, corpus_key: lQ)
# score: 0.3966216832645025,
#        (n_topics: 25, window_size: 10, corpus_key: lqA)
# score: 0.2871142055318179,
#        (n_topics: 30, window_size: 30, corpus_key: lqa)
# score: 0.28334256611253134,
#        (n_topics: 30, window_size: 35, corpus_key: lqa)
# score: 0.3354193541086514,
#        (n_topics: 15, window_size: 10, corpus_key: lQ)
# score: 0.3153422132305598,
#        (n_topics: 10, window_size: 30, corpus_key: lqA)
# score: 0.4855116634092362,
#        (n_topics: 15, window_size: 5, corpus_key: lQA)
# score: 0.200827519042241,
#        (n_topics: 30, window_size: 20, corpus_key: lQa)
# score: 0.2097719634369022,
#        (n_topics: 25, window_size: 25, corpus_key: lQ)
# score: 0.32635187863188714,
#        (n_topics: 15, window_size: 35, corpus_key: lQ)
# score: 0.4334743605548823,
#        (n_topics: 20, window_size: 5, corpus_key: lqA)
# score: 0.32804896097012937,
#        (n_topics: 15, window_size: 10, corpus_key: lqA)
# score: 0.3099702557985058,
#        (n_topics: 5, window_size: 30, corpus_key: lqA)
# score: 0.4919355122048848,
#        (n_topics: 5, window_size: 25, corpus_key: lQa)
# score: 0.460250533341123,
#        (n_topics: 25, window_size: 15, corpus_key: lQa)
# score: 0.42346305006338647,
#        (n_topics: 20, window_size: 25, corpus_key: lQ)
# score: 0.3615590785236305,
#        (n_topics: 10, window_size: 15, corpus_key: l)
# score: 0.418781469106395,
#        (n_topics: 25, window_size: 35, corpus_key: lQ)
# score: 0.3614828225040181,
#        (n_topics: 15, window_size: 35, corpus_key: lqA)
# score: 0.37078431382565624,
#        (n_topics: 25, window_size: 30, corpus_key: lQA)
# score: 0.2845096044155709,
#        (n_topics: 15, window_size: 35, corpus_key: lq)
# score: 0.3276340706709397,
#        (n_topics: 20, window_size: 20, corpus_key: l)
# score: 0.44589930620416085,
#        (n_topics: 25, window_size: 30, corpus_key: lQa)
# score: 0.26088153099295597,
#        (n_topics: 15, window_size: 30, corpus_key: lq)
# score: 0.3823487298302452,
#        (n_topics: 10, window_size: 30, corpus_key: lQA)
# score: 0.5157230858009155,
#        (n_topics: 20, window_size: 5, corpus_key: l)
# score: 0.46960776043426145,
#        (n_topics: 10, window_size: 15, corpus_key: lQa)
# score: 0.4812441847246146,
#        (n_topics: 35, window_size: 5, corpus_key: lqa)
# score: 0.17275993840608728,
#        (n_topics: 5, window_size: 25, corpus_key: lqA)
# score: 0.5218863688196822,
#        (n_topics: 5, window_size: 30, corpus_key: lQ)
# score: 0.3512762060207159,
#        (n_topics: 30, window_size: 5, corpus_key: l)
# score: 0.2013768439027953,
#        (n_topics: 35, window_size: 5, corpus_key: lQa)
# score: 0.3149103817404698,
#        (n_topics: 30, window_size: 15, corpus_key: lQA)
# score: 0.29030032846463133,
#        (n_topics: 10, window_size: 15, corpus_key: lQ)
# score: 0.33401891711787635,
#        (n_topics: 35, window_size: 25, corpus_key: lQA)
# score: 0.11638422936473741,
#        (n_topics: 25, window_size: 10, corpus_key: lQA)
# score: 0.14498513724919854,
#        (n_topics: 35, window_size: 20, corpus_key: lQa)
# score: 0.10622548459051985,
#        (n_topics: 15, window_size: 10, corpus_key: l)
# score: 0.438167716972042,
#        (n_topics: 35, window_size: 30, corpus_key: lQA)
# score: 0.1773943475161749,
#        (n_topics: 25, window_size: 30, corpus_key: lqa)
# score: 0.258369579613312,
#        (n_topics: 30, window_size: 25, corpus_key: lQ)
# score: 0.37581299863177275,
#        (n_topics: 10, window_size: 20, corpus_key: lqA)
# score: 0.3739807704710983,
#        (n_topics: 15, window_size: 30, corpus_key: lQ)
# score: 0.29331095774181376,
#        (n_topics: 15, window_size: 10, corpus_key: lQa)
# score: 0.49425853306527245,
#        (n_topics: 20, window_size: 15, corpus_key: lQA)
# score: 0.320898465556698,
#        (n_topics: 15, window_size: 25, corpus_key: lqa)
# score: 0.4314981972438907,
#        (n_topics: 25, window_size: 10, corpus_key: lQa)
# score: 0.36722177734940825,
#        (n_topics: 20, window_size: 15, corpus_key: lqa)
# score: 0.3020036253512071,
#        (n_topics: 10, window_size: 5, corpus_key: lqA)
# score: 0.24352884570167768,
#        (n_topics: 5, window_size: 10, corpus_key: lQA)
# score: 0.035638797663521196,
#        (n_topics: 10, window_size: 35, corpus_key: lq)
# score: 0.3580171917562496,
#        (n_topics: 5, window_size: 5, corpus_key: lQA)
# score: 0.06706540375217979,
#        (n_topics: 25, window_size: 20, corpus_key: lq)
# score: 0.21200262957466837,
#        (n_topics: 15, window_size: 15, corpus_key: lq)
# score: 0.48315837293439634,
#        (n_topics: 10, window_size: 35, corpus_key: lQ)
# score: 0.6256934163534982,
#        (n_topics: 10, window_size: 25, corpus_key: lQA)
# score: 0.4280855822235293,
#        (n_topics: 30, window_size: 35, corpus_key: lQA)
# score: 0.22447748074141846,
#        (n_topics: 5, window_size: 25, corpus_key: lQA)
# score: 0.332145971207344,
#        (n_topics: 30, window_size: 5, corpus_key: lQ)
# score: 0.5180073839645174,
#        (n_topics: 25, window_size: 25, corpus_key: lqa)
# score: 0.22120298823311918,
#        (n_topics: 35, window_size: 35, corpus_key: lQA)
# score: 0.07849933152217939,
#        (n_topics: 5, window_size: 30, corpus_key: l)
# score: 0.5425252537081753,
#        (n_topics: 10, window_size: 30, corpus_key: lqa)
# score: 0.5212149701490044,
#        (n_topics: 30, window_size: 10, corpus_key: lQ)
# score: 0.36809797631411806,
#        (n_topics: 5, window_size: 35, corpus_key: lqA)
# score: 0.5877621741440817,
#        (n_topics: 5, window_size: 35, corpus_key: lq)
# score: 0.39076933086010246,
#        (n_topics: 15, window_size: 10, corpus_key: lQA)
# score: 0.3287988074131168,
#        (n_topics: 35, window_size: 25, corpus_key: lQa)
# score: 0.26450717760497544,
#        (n_topics: 20, window_size: 15, corpus_key: lQa)
# score: 0.396211549467277,
#        (n_topics: 10, window_size: 15, corpus_key: lqA)
# score: 0.40715404426628554,
#        (n_topics: 20, window_size: 30, corpus_key: lQ)
# score: 0.36532604347930087,
#        (n_topics: 30, window_size: 5, corpus_key: lqA)
# score: 0.28849582743245433,
#        (n_topics: 35, window_size: 15, corpus_key: lqa)
# score: 0.16080745209932135,
#        (n_topics: 25, window_size: 15, corpus_key: lQ)
# score: 0.30209140150241526,
#        (n_topics: 30, window_size: 35, corpus_key: lQ)
# score: 0.2905765343096309,
#        (n_topics: 5, window_size: 15, corpus_key: l)
# score: 0.3644197654090543,
#        (n_topics: 30, window_size: 30, corpus_key: lQA)
# score: 0.3254306196346133,
#        (n_topics: 35, window_size: 25, corpus_key: lqA)
# score: 0.24275793350232291,
#        (n_topics: 5, window_size: 20, corpus_key: lqa)
# score: 0.5398102118360344,
#        (n_topics: 15, window_size: 5, corpus_key: lqa)
# score: 0.3182372585091643,
#        (n_topics: 10, window_size: 5, corpus_key: lqa)
# score: 0.2831732164096298,
#        (n_topics: 30, window_size: 10, corpus_key: lQA)
# score: 0.2054772527762393,
#        (n_topics: 25, window_size: 15, corpus_key: lqa)
# score: 0.35891800724662837,
#        (n_topics: 10, window_size: 5, corpus_key: lq)
# score: 0.1649783452902349,
#        (n_topics: 35, window_size: 25, corpus_key: lq)
# score: 0.12913667763674183,
#        (n_topics: 20, window_size: 30, corpus_key: lqA)
# score: 0.21682338920265498,
#        (n_topics: 30, window_size: 35, corpus_key: lq)
# score: 0.25653893830661684,
#        (n_topics: 10, window_size: 35, corpus_key: lQa)
# score: 0.48333862123325666,
#        (n_topics: 5, window_size: 10, corpus_key: lq)
# score: 0.26203280026919795,
#        (n_topics: 30, window_size: 35, corpus_key: lqA)
# score: 0.09428632058089119,
#        (n_topics: 35, window_size: 10, corpus_key: l)
# score: 0.2759816658545891,
#        (n_topics: 30, window_size: 35, corpus_key: lQa)
# score: 0.2780639712913972,
#        (n_topics: 35, window_size: 20, corpus_key: lQ)
# score: 0.08640954056662561,
#        (n_topics: 15, window_size: 20, corpus_key: lq)
# score: 0.263221411083174,
#        (n_topics: 35, window_size: 5, corpus_key: lQ)
# score: 0.4499070047108303,
#        (n_topics: 5, window_size: 25, corpus_key: l)
# score: 0.22820786528814369,
#        (n_topics: 20, window_size: 5, corpus_key: lQa)
# score: 0.3147504380469453,
#        (n_topics: 5, window_size: 5, corpus_key: lqA)
# score: 0.26799925201923747,
#        (n_topics: 30, window_size: 5, corpus_key: lq)
# score: 0.36131865867536406,
#        (n_topics: 15, window_size: 20, corpus_key: lQ)
# score: 0.26866962490072144,
#        (n_topics: 30, window_size: 25, corpus_key: lQA)
# score: 0.18643850939060094,
#        (n_topics: 10, window_size: 25, corpus_key: lqA)
# score: 0.44822541222633205,
#        (n_topics: 15, window_size: 15, corpus_key: lqa)
# score: 0.5297171798541549,
#        (n_topics: 30, window_size: 15, corpus_key: lQa)
# score: 0.20722749931060014,
#        (n_topics: 5, window_size: 35, corpus_key: lQA)
# score: 0.2768928224883126,
#        (n_topics: 5, window_size: 20, corpus_key: lQ)
# score: 0.3292019897381879,
#        (n_topics: 35, window_size: 30, corpus_key: lQ)
# score: 0.31925178778948354,
#        (n_topics: 25, window_size: 30, corpus_key: lqA)
# score: 0.09888449179629405,
#        (n_topics: 35, window_size: 20, corpus_key: lqA)
# score: 0.2500454496129347,
#        (n_topics: 5, window_size: 35, corpus_key: lQ)
# score: 0.43474763469796596,
#        (n_topics: 5, window_size: 30, corpus_key: lQA)
# score: 0.26568737540637377,
#        (n_topics: 25, window_size: 10, corpus_key: lqa)
# score: 0.410783276973965,
#        (n_topics: 10, window_size: 20, corpus_key: lQa)
# score: 0.4717068880384615,
#        (n_topics: 20, window_size: 5, corpus_key: lqa)
# score: 0.3988220855703054,
#        (n_topics: 5, window_size: 25, corpus_key: lQ)
# score: 0.4209002718686544,
#        (n_topics: 20, window_size: 10, corpus_key: lQ)
# score: 0.34379709685400206,
#        (n_topics: 10, window_size: 35, corpus_key: lqA)
# score: 0.45839066089066516,
#        (n_topics: 10, window_size: 5, corpus_key: lQ)
# score: 0.084323911523715,
#        (n_topics: 35, window_size: 20, corpus_key: lq)
# score: 0.08738832258866935,
#        (n_topics: 35, window_size: 35, corpus_key: lqA)
# score: 0.18195013822794895,
#        (n_topics: 30, window_size: 20, corpus_key: lqa)
# score: 0.2499854426126938,
#        (n_topics: 20, window_size: 20, corpus_key: lQ)
# score: 0.11284668351083937,
#        (n_topics: 5, window_size: 15, corpus_key: lQA)
# score: 0.15828762531271162,
#        (n_topics: 10, window_size: 5, corpus_key: l)
# score: 0.26843370843835546,
#        (n_topics: 35, window_size: 15, corpus_key: lq)
# score: 0.28123928178403057,
#        (n_topics: 15, window_size: 5, corpus_key: lq)
# score: 0.32373456486728247,
#        (n_topics: 20, window_size: 10, corpus_key: lqa)
# score: 0.20501165959970927,
#        (n_topics: 5, window_size: 30, corpus_key: lq)
# score: 0.327059428863851,
#        (n_topics: 10, window_size: 30, corpus_key: lQ)
# score: 0.6339909838434689,
#        (n_topics: 5, window_size: 25, corpus_key: lq)
# score: 0.3001243770205345,
#        (n_topics: 10, window_size: 25, corpus_key: lq)
# score: 0.4153570329372199,
#        (n_topics: 35, window_size: 15, corpus_key: lQA)
# score: 0.4046750629299972,
#        (n_topics: 20, window_size: 10, corpus_key: lqA)
# score: 0.3857508156704115,
#        (n_topics: 5, window_size: 10, corpus_key: lQa)
# score: 0.3709927810453275,
#        (n_topics: 5, window_size: 30, corpus_key: lQa)
# score: 0.3560624153402699,
#        (n_topics: 5, window_size: 35, corpus_key: lQa)
# score: 0.48007584203059717,
#        (n_topics: 10, window_size: 10, corpus_key: lq)
# score: 0.46855603344489183,
#        (n_topics: 25, window_size: 25, corpus_key: lQA)
# score: 0.4157323738309038,
#        (n_topics: 35, window_size: 10, corpus_key: lQA)
# score: 0.2103587975829575,
#        (n_topics: 30, window_size: 25, corpus_key: lq)
# score: 0.242530041176644,
#        (n_topics: 20, window_size: 5, corpus_key: lQ)
# score: 0.28541973678003957,
#        (n_topics: 25, window_size: 5, corpus_key: lQ)
# score: 0.35341628086671917,
#        (n_topics: 5, window_size: 15, corpus_key: lQa)
# score: 0.5624871389852164,
#        (n_topics: 25, window_size: 5, corpus_key: lqA)
# score: 0.2994539549480715,
#        (n_topics: 5, window_size: 10, corpus_key: l)
# score: 0.3318501455019522,
#        (n_topics: 30, window_size: 5, corpus_key: lQa)
# score: 0.2479250499677076,
#        (n_topics: 25, window_size: 5, corpus_key: l)
# score: 0.32975980902606206,
#        (n_topics: 10, window_size: 30, corpus_key: lq)
# score: 0.3222373174665737,
#        (n_topics: 5, window_size: 20, corpus_key: lq)
# score: 0.438900894570165,
#        (n_topics: 5, window_size: 20, corpus_key: lQA)
# score: 0.14516000979693838,
#        (n_topics: 30, window_size: 5, corpus_key: lqa)
# score: 0.09171357287081265,
#        (n_topics: 35, window_size: 35, corpus_key: lqa)
# score: 0.21739431943493254,
#        (n_topics: 5, window_size: 35, corpus_key: lqa)
# score: 0.5768808407673512,
#        (n_topics: 10, window_size: 20, corpus_key: lQ)
# score: 0.4522836895276525,
#        (n_topics: 5, window_size: 15, corpus_key: lqa)
# score: 0.24274149923733584,
#        (n_topics: 10, window_size: 5, corpus_key: lQA)
# score: 0.09780176766581647,
#        (n_topics: 35, window_size: 25, corpus_key: lQ)
# score: 0.23417611379776027,
#        (n_topics: 25, window_size: 20, corpus_key: lQa)
# score: 0.34645905859741827,
#        (n_topics: 10, window_size: 10, corpus_key: lQ)
# score: 0.07428506954035569,
#        (n_topics: 20, window_size: 10, corpus_key: lQA)
# score: 0.354356919660863,
#        (n_topics: 5, window_size: 5, corpus_key: lQ)
# score: 0.18721255367369022,
#        (n_topics: 10, window_size: 25, corpus_key: lqa)
# score: 0.2022953417116659,
#        (n_topics: 25, window_size: 5, corpus_key: lQa)
# score: 0.2121045153199196,
#        (n_topics: 10, window_size: 25, corpus_key: lQ)
# score: 0.5132994882430094,
#        (n_topics: 35, window_size: 30, corpus_key: lQa)
# score: 0.19429862676531595,
#        (n_topics: 15, window_size: 5, corpus_key: lqA)
# score: 0.2657049437116859,
#        (n_topics: 25, window_size: 5, corpus_key: lqa)
# score: 0.3088976328352856,
#        (n_topics: 10, window_size: 20, corpus_key: lq)
# score: 0.3189425717712745,
#        (n_topics: 30, window_size: 10, corpus_key: lQa)
# score: 0.09190727283896272,
#        (n_topics: 15, window_size: 10, corpus_key: lqa)
# score: 0.3616253735448738,
#        (n_topics: 35, window_size: 30, corpus_key: lqa)
# score: 0.15052138599803863,
#        (n_topics: 10, window_size: 10, corpus_key: lqA)
# score: 0.2826082332366694,
#        (n_topics: 5, window_size: 25, corpus_key: lqa)
# score: 0.38758532346600005,
#        (n_topics: 10, window_size: 15, corpus_key: lqa)
# score: 0.55428834612371,
#        (n_topics: 10, window_size: 20, corpus_key: lqa)
# score: 0.519558772839688,
#        (n_topics: 5, window_size: 10, corpus_key: lqa)
# score: 0.07896879875042759,
#        (n_topics: 10, window_size: 10, corpus_key: lqa)
# score: 0.25557497735570867,
#        (n_topics: 35, window_size: 30, corpus_key: lqA)
# score: 0.13076589207441436,
#        (n_topics: 5, window_size: 10, corpus_key: lqA)
# score: 0.3456217156231064,
#        (n_topics: 15, window_size: 5, corpus_key: lQa)
# score: 0.16824864884760293,
#        (n_topics: 5, window_size: 5, corpus_key: lq)
# score: 0.16587721045541448,
#        (n_topics: 15, window_size: 5, corpus_key: lQ)
# score: 0.22960366382670017,
#        (n_topics: 5, window_size: 5, corpus_key: lqa)
# score: 0.3662921619068233,
#        (n_topics: 5, window_size: 15, corpus_key: lq)
# score: 0.2929359027944578,
#        (n_topics: 10, window_size: 5, corpus_key: lQa)
# score: 0.11544512186727364,
#        (n_topics: 10, window_size: 15, corpus_key: lQA)
# score: 0.3368751085295737,
#        (n_topics: 10, window_size: 35, corpus_key: lQA)
# score: 0.2983030780314555,
#        (n_topics: 5, window_size: 30, corpus_key: lqa)
# score: 0.5542293321012755,
#        (n_topics: 5, window_size: 5, corpus_key: l)
# score: 0.0852832755231375,
#        (n_topics: 35, window_size: 35, corpus_key: lQ)
# score: 0.2418568735858055,
#        (n_topics: 10, window_size: 10, corpus_key: lQa)
# score: 0.4014043614152181,
#        (n_topics: 20, window_size: 35, corpus_key: lqa)
# score: 0.4242011322446114,
#        (n_topics: 10, window_size: 15, corpus_key: lq)
# score: 0.24358571037163668,
#        (n_topics: 10, window_size: 10, corpus_key: lQA)
# score: 0.13069117516076043], dtype=object)

# %%
pm = model_params(10,25, 'lqA', PARAM_MODELS)

# %%
pm.plot_topics()

# %%
pm.plot_heatmaps()

# %%
pm.plot_corr_timeseries()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))
sns.heatmap((1-cdist(pm.forces_traj, pm.forces_questions, 'correlation')).T, 
            vmin=0, vmax=1, ax=ax1)
ax1.set_title('forces')
sns.heatmap((1-cdist(pm.bos_traj, pm.bos_questions, 'correlation')).T, 
            vmin=0, vmax=1, ax=ax2)
ax2.set_title('bos')
plt.show()

# %%
bos_lq_corrs = 1 - cdist(pm.bos_traj, pm.bos_questions, 'correlation')
for i in range(15):
    plt.plot(bos_lq_corrs[:, i])
    plt.ylim(bos_lq_corrs.min(), 1)
    plt.title(i)
    plt.show()

# %%
pm.bos_questions[4]
# Out:
# array([0.15655207, 0.01428571, 0.01429262, 0.41001378, 0.01429326,
#        0.01429464, 0.0142918 , 0.01429011, 0.01428627, 0.33339974])

# %%
pm.plot_hypertools()
# Out:
# /opt/conda/lib/python3.7/site-packages/hypertools/plot/plot.py:414: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
pm.plot_hypertools(reducer='UMAP')
# Out:
# /opt/conda/lib/python3.7/site-packages/hypertools/plot/plot.py:414: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
pm.plot_qcorr_dists()

# %%
for topic, words in get_top_words(pm.cv, pm.lda).items():
    print(f'topic {topic + 1}:\n\t{", ".join(words)}')
# Out:
# topic 1:
# 	universe, large, follow, gravity, attract, object, mass, whole, operate, snowball
# topic 2:
# 	force, strong, start, strength, super, even, distance, see, interaction, electromagnetic
# topic 3:
# 	force, detail, frame, different, one, electron, strong, connect, lot, reference
# topic 4:
# 	scale, force, even, gravity, actual, weak, keep, around, orbit, surprise
# topic 5:
# 	charge, mass, attract, gravity, large, neutral, big, lump, concentration, huge
# topic 6:
# 	proton, weak, neutron, interaction, one, cesium, nucleon, extra, give, example
# topic 7:
# 	force, huge, charge, coulomb, magnet, side, electromagnetic, call, way, electrostatic
# topic 8:
# 	atom, hydrogen, dense, huge, cloud, would, slow, mass, condense, center
# topic 9:
# 	force, two, electron, strong, charge, atom, coulomb, nucleus, chemistry, well
# topic 10:
# 	helium, mass, star, hydrogen, atomic, fuse, energy, temperature, super, high
# topic 11:
# 	least, visualize, hard, intuitive, move, call, sometimes, dominate, interaction, radioactive
# topic 12:
# 	actual, force, nucleus, enough, much, hydrogen, atom, two, want, proton
# topic 13:
# 	hydrogen, one, fuse, two, proton, helium, deuterium, neutron, table, periodic
# topic 14:
# 	force, gravity, weak, apply, distance, interaction, strong, electromagnetic, relative, actual
# topic 15:
# 	mass, pressure, fusion, enough, actual, occur, ignition, energy, threshold, result

# %%
all_questions = np.concatenate((pm.forces_questions, pm.bos_questions, pm.gen_questions))
sns.heatmap(np.corrcoef(all_questions), vmin=-1, vmax=1)

# %%
all_words = ' '.join(ff_lines_processed + bos_lines_processed + quiz_text_processed.ravel().tolist()).split()
all_question_words = ' '.join(quiz_text_processed.ravel()).split()

# %%
from collections import Counter

wordcounts = Counter()
for word in all_words:
    wordcounts[word] += 1

# %%
wordcounts.most_common()
# Out:
# [('force', 90),
#  ('atom', 54),
#  ('mass', 50),
#  ('gravity', 41),
#  ('strong', 36),
#  ('weak', 35),
#  ('charge', 34),
#  ('hydrogen', 32),
#  ('interaction', 31),
#  ('proton', 30),
#  ('actual', 28),
#  ('electromagnetic', 28),
#  ('nucleus', 28),
#  ('go', 26),
#  ('two', 26),
#  ('small', 24),
#  ('distance', 22),
#  ('huge', 22),
#  ('follow', 22),
#  ('electron', 20),
#  ('would', 20),
#  ('star', 20),
#  ('temperature', 19),
#  ('fusion', 19),
#  ('neutron', 18),
#  ('pressure', 18),
#  ('keep', 16),
#  ('even', 16),
#  ('one', 16),
#  ('large', 16),
#  ('helium', 16),
#  ('enough', 15),
#  ('object', 15),
#  ('fuse', 15),
#  ('coulomb', 14),
#  ('scale', 13),
#  ('attraction', 13),
#  ('together', 12),
#  ('occur', 12),
#  ('act', 12),
#  ('sun', 11),
#  ('way', 11),
#  ('computer', 11),
#  ('gravitational', 11),
#  ('see', 11),
#  ('different', 11),
#  ('happen', 11),
#  ('attract', 11),
#  ('call', 10),
#  ('well', 10),
#  ('cloud', 10),
#  ('dense', 10),
#  ('universe', 9),
#  ('start', 9),
#  ('repel', 9),
#  ('number', 9),
#  ('time', 9),
#  ('apply', 9),
#  ('positive', 9),
#  ('close', 9),
#  ('energy', 9),
#  ('around', 8),
#  ('earth', 8),
#  ('center', 8),
#  ('much', 8),
#  ('negative', 8),
#  ('combine', 8),
#  ('ignition', 8),
#  ('want', 7),
#  ('give', 7),
#  ('high', 7),
#  ('galaxy', 7),
#  ('atomic', 7),
#  ('draw', 7),
#  ('move', 7),
#  ('relative', 7),
#  ('tend', 7),
#  ('slow', 7),
#  ('repulsion', 7),
#  ('say', 6),
#  ('detail', 6),
#  ('reason', 6),
#  ('know', 6),
#  ('concentration', 6),
#  ('low', 6),
#  ('increase', 6),
#  ('might', 5),
#  ('orbit', 5),
#  ('little', 5),
#  ('chemistry', 5),
#  ('cesium', 5),
#  ('nucleon', 5),
#  ('something', 5),
#  ('next', 5),
#  ('strength', 5),
#  ('operate', 5),
#  ('first', 5),
#  ('could', 5),
#  ('super', 5),
#  ('kelvin', 5),
#  ('result', 5),
#  ('sequence', 5),
#  ('video', 4),
#  ('four', 4),
#  ('fundamental', 4),
#  ('sense', 4),
#  ('magnet', 4),
#  ('talk', 4),
#  ('example', 4),
#  ('obvious', 4),
#  ('away', 4),
#  ('attractive', 4),
#  ('frame', 4),
#  ('mind', 4),
#  ('fast', 4),
#  ('become', 4),
#  ('another', 4),
#  ('condense', 4),
#  ('provide', 4),
#  ('collapse', 4),
#  ('reaction', 4),
#  ('deuterium', 4),
#  ('main', 4),
#  ('threshold', 4),
#  ('effect', 4),
#  ('similar', 4),
#  ('density', 4),
#  ('solar', 4),
#  ('system', 4),
#  ('balloon', 4),
#  ('level', 3),
#  ('surprise', 3),
#  ('jump', 3),
#  ('planet', 3),
#  ('make', 3),
#  ('think', 3),
#  ('human', 3),
#  ('type', 3),
#  ('less', 3),
#  ('never', 3),
#  ('least', 3),
#  ('responsible', 3),
#  ('either', 3),
#  ('turn', 3),
#  ('extra', 3),
#  ('particle', 3),
#  ('pull', 3),
#  ('th', 3),
#  ('anything', 3),
#  ('macro', 3),
#  ('though', 3),
#  ('repulsive', 3),
#  ('electrostatic', 3),
#  ('side', 3),
#  ('play', 3),
#  ('view', 3),
#  ('reference', 3),
#  ('lot', 3),
#  ('float', 3),
#  ('neutral', 3),
#  ('process', 3),
#  ('massive', 3),
#  ('idea', 3),
#  ('million', 3),
#  ('combustion', 3),
#  ('oxygen', 3),
#  ('outward', 3),
#  ('balance', 3),
#  ('release', 3),
#  ('core', 3),
#  ('cause', 3),
#  ('experience', 3),
#  ('extreme', 3),
#  ('describe', 3),
#  ('decrease', 3),
#  ('supermassive', 3),
#  ('order', 3),
#  ('none', 3),
#  ('glue', 2),
#  ('milky', 2),
#  ('maybe', 2),
#  ('notice', 2),
#  ('although', 2),
#  ('dominate', 2),
#  ('sometimes', 2),
#  ('radioactive', 2),
#  ('decay', 2),
#  ('particular', 2),
#  ('beta', 2),
#  ('plus', 2),
#  ('essential', 2),
#  ('quark', 2),
#  ('flip', 2),
#  ('anti', 2),
#  ('neutrino', 2),
#  ('traditional', 2),
#  ('push', 2),
#  ('come', 2),
#  ('subatomic', 2),
#  ('familiar', 2),
#  ('deal', 2),
#  ('electromagnetism', 2),
#  ('write', 2),
#  ('magnetism', 2),
#  ('sort', 2),
#  ('magnetic', 2),
#  ('opposite', 2),
#  ('connect', 2),
#  ('probably', 2),
#  ('best', 2),
#  ('yet', 2),
#  ('class', 2),
#  ('learn', 2),
#  ('try', 2),
#  ('question', 2),
#  ('may', 2),
#  ('net', 2),
#  ('explain', 2),
#  ('right', 2),
#  ('guy', 2),
#  ('run', 2),
#  ('able', 2),
#  ('die', 2),
#  ('radius', 2),
#  ('big', 2),
#  ('lump', 2),
#  ('interact', 2),
#  ('imagine', 2),
#  ('space', 2),
#  ('remember', 2),
#  ('amount', 2),
#  ('approach', 2),
#  ('point', 2),
#  ('neat', 2),
#  ('anyway', 2),
#  ('overcome', 2),
#  ('carbon', 2),
#  ('molecule', 2),
#  ('slight', 2),
#  ('stage', 2),
#  ('original', 2),
#  ('still', 2),
#  ('heavy', 2),
#  ('eventual', 2),
#  ('periodic', 2),
#  ('table', 2),
#  ('show', 2),
#  ('form', 2),
#  ('quite', 2),
#  ('generate', 2),
#  ('heat', 2),
#  ('jupiter', 2),
#  ('due', 2),
#  ('neither', 2),
#  ('significant', 2),
#  ('convert', 2),
#  ('satellite', 2),
#  ('exert', 2),
#  ('distant', 2),
#  ('rough', 2),
#  ('many', 2),
#  ('consider', 2),
#  ('distribution', 2),
#  ('equal', 2),
#  ('product', 2),
#  ('term', 2),
#  ('list', 2),
#  ('element', 2),
#  ('expand', 2),
#  ('shrink', 2),
#  ('overview', 1),
#  ('wow', 1),
#  ('moon', 1),
#  ('molecular', 1),
#  ('monitor', 1),
#  ('cell', 1),
#  ('phone', 1),
#  ('wallet', 1),
#  ('matter', 1),
#  ('hard', 1),
#  ('visualize', 1),
#  ('intuitive', 1),
#  ('minus', 1),
#  ('mean', 1),
#  ('add', 1),
#  ('exact', 1),
#  ('math', 1),
#  ('pretty', 1),
#  ('hairy', 1),
#  ('instead', 1),
#  ('barium', 1),
#  ('emit', 1),
#  ('complete', 1),
#  ('associate', 1),
#  ('intergalactic', 1),
#  ('beyond', 1),
#  ('disappear', 1),
#  ('hierarchy', 1),
#  ('magenta', 1),
#  ('put', 1),
#  ('place', 1),
#  ('unbelievably', 1),
#  ('nothing', 1),
#  ('reality', 1),
#  ('wonder', 1),
#  ('everyday', 1),
#  ('life', 1),
#  ('multiple', 1),
#  ('word', 1),
#  ('guess', 1),
#  ('part', 1),
#  ('fridge', 1),
#  ('pole', 1),
#  ('back', 1),
#  ('future', 1),
#  ('intuition', 1),
#  ('apparent', 1),
#  ('relativistic', 1),
#  ('name', 1),
#  ('circulate', 1),
#  ('size', 1),
#  ('saw', 1),
#  ('model', 1),
#  ('sit', 1),
#  ('stick', 1),
#  ('subnucleic', 1),
#  ('specially', 1),
#  ('theory', 1),
#  ('equalize', 1),
#  ('else', 1),
#  ('snowball', 1),
#  ('whole', 1),
#  ('normally', 1),
#  ('affect', 1),
#  ('towards', 1),
#  ('forward', 1),
#  ('bump', 1),
#  ('rub', 1),
#  ('interest', 1),
#  ('bunch', 1),
#  ('inward', 1),
#  ('everything', 1),
#  ('entire', 1),
#  ('realize', 1),
#  ('look', 1),
#  ('focus', 1),
#  ('anywhere', 1),
#  ('near', 1),
#  ('somehow', 1),
#  ('sudden', 1),
#  ('overtake', 1),
#  ('nuclei', 1),
#  ('hot', 1),
#  ('bring', 1),
#  ('careful', 1),
#  ('burn', 1),
#  ('presence', 1),
#  ('degrade', 1),
#  ('step', 1),
#  ('basic', 1),
#  ('trouble', 1),
#  ('spell', 1),
#  ('end', 1),
#  ('oh', 1),
#  ('lose', 1),
#  ('state', 1),
#  ('definition', 1),
#  ('isotope', 1),
#  ('ton', 1),
#  ('produce', 1),
#  ('constituent', 1),
#  ('need', 1),
#  ('use', 1),
#  ('inside', 1),
#  ('several', 1),
#  ('reach', 1),
#  ('certain', 1),
#  ('general', 1),
#  ('ball', 1),
#  ('exist', 1),
#  ('fuel', 1),
#  ('noticable', 1),
#  ('detect', 1),
#  ('disrupt', 1),
#  ('field', 1),
#  ('lead', 1),
#  ('light', 1),
#  ('collide', 1),
#  ('bound', 1),
#  ('resist', 1),
#  ('separation', 1),
#  ('despite', 1),
#  ('detectable', 1),
#  ('counteract', 1),
#  ('induce', 1),
#  ('difference', 1),
#  ('ever', 1),
#  ('powerful', 1),
#  ('electricity', 1),
#  ('case', 1),
#  ('switch', 1),
#  ('property', 1),
#  ('primary', 1),
#  ('opposition', 1),
#  ('uneven', 1),
#  ('cancel', 1),
#  ('grow', 1),
#  ('body', 1),
#  ('tremendous', 1),
#  ('contain', 1),
#  ('apart', 1),
#  ('similarity', 1),
#  ('true', 1),
#  ('far', 1),
#  ('refer', 1),
#  ('spin', 1),
#  ('billion', 1),
#  ('prevent', 1),
#  ('nearby', 1),
#  ('reverse', 1),
#  ('beryllium', 1),
#  ('compare', 1),
#  ('possible', 1),
#  ('tell', 1),
#  ('comprise', 1),
#  ('volume', 1),
#  ('accurate', 1),
#  ('alternative', 1),
#  ('decomposition', 1),
#  ('displacement', 1),
#  ('electrom', 1),
#  ('define', 1),
#  ('suppose', 1),
#  ('change', 1),
#  ('conversion', 1),
#  ('unit', 1),
#  ('velocity', 1),
#  ('locate', 1),
#  ('percent', 1),
#  ('occupy', 1),
#  ('famous', 1),
#  ('equation', 1),
#  ('attribute', 1),
#  ('albert', 1),
#  ('einstein', 1),
#  ('mc', 1),
#  ('letter', 1),
#  ('represent', 1),
#  ('momentum', 1),
#  ('moment', 1),
#  ('inertia', 1),
#  ('mole', 1),
#  ('inflate', 1),
#  ('answer', 1),
#  ('correct', 1),
#  ('depend', 1),
#  ('whether', 1),
#  ('fill', 1),
#  ('air', 1),
#  ('gas', 1)]

# %%
cols = ['Number of topics', 'Lecture window length', 'Corpus', 'score']
gs_results = pd.DataFrame(columns=cols)
for ix, obj in enumerate(PARAM_MODELS):
    gs_results.loc[ix] = [obj.n_topics, obj.window_size, obj.corpus_key, obj.score]
    
# gs_results.to_pickle(DATA_DIR.joinpath('grid_search_results.p'))
# gs_results = pd.read_pickle(DATA_DIR.joinpath('grid_search_results.p'))

# %%
max_score = gs_results['score'].max()
g = sns.FacetGrid(gs_results, col='Corpus', col_wrap=4)
g.map_dataframe(corpus_heatmap, 
                'Number of topics', 
                'Lecture window length', 
                max_score, 
                vmin=0, 
                vmax=0.6)

g.set_titles('{col_var}: {col_name}', size='x-large')
g.set_xlabels(size='large')
g.set_ylabels(size='large')

# g.savefig(FIG_DIR.joinpath('parameter_search.pdf'), bbox_inches='tight')
