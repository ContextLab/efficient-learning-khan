# %% [markdown]
# # imports

# %%
import glob, os, sys, io, skvideo.io, argparse, math, datetime, ffmpy, shutil, wikipedia
from google.cloud import videointelligence_v1p1beta1 as videointelligence
from google.cloud import vision
from google.cloud import storage
from google.cloud.vision import types
from google.oauth2 import service_account
from PIL import Image, ImageDraw
import numpy as np
import deepdish as dd

# %%
# credential path must be set outside function
credentials = service_account.Credentials.from_service_account_file('../../google-credentials/memory-dynamics-73f025c2a094.json')

# %% [markdown]
# # feature extraction with google cloud video intelligence api

# %%
def extract_features(movie_to_process, bucket_name):
    
    #path to video input file and JSON output file
    #input_uri = 'gs://' + bucket_name + '/video_processing/' + movie_to_process
    input_uri = 'gs://sherlock_movie/sherlock-mini-test.mp4'
    
    video_client = videointelligence.VideoIntelligenceServiceClient(credentials=credentials)
    
    # request extracted features
    features = [videointelligence.enums.Feature.LABEL_DETECTION, videointelligence.enums.Feature.SPEECH_TRANSCRIPTION]

    # request shot-level and frame_level labels, assign to label detection config
    label_mode = videointelligence.enums.LabelDetectionMode.SHOT_AND_FRAME_MODE
    label_config = videointelligence.types.LabelDetectionConfig(label_detection_mode=label_mode)
    
    # set language context to British english FOR SHERLOCK
    speech_config = videointelligence.types.SpeechTranscriptionConfig(language_code='en-GB')
    
    # pass label detection and speech transcription configs to context 
    context = videointelligence.types.VideoContext(label_detection_config=label_config, speech_transcription_config=speech_config)

    # define analysis from parameters
    operation = video_client.annotate_video(input_uri, features=features, video_context=context)
    print('processing video')
    
    # check if operation is done every 90s, return if done
    result = operation.result(timeout=5000)
    print('finished processing video')
    
    return result

# %%
# test
test_result = extract_features('sherlock-mini-test.mp4','sherlock_movie')
# Out:
# processing video
#
# finished processing video

# %%
dd.io.save('../data/gcloud outputs/sherlock-mini-test', test_result)

# %%
# movie_to_process is sherlock_video.mp4
# bucket is sherlock_movie

# where do I want to output to?

# %%
# Out:
# annotation_results {
#   input_uri: "/sherlock_movie/sherlock-mini-test.mp4"
#   segment_label_annotations {
#     entity {
#       entity_id: "/m/09kqc"
#       description: "humour"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#         }
#         end_time_offset {
#           seconds: 45
#           nanos: 40000000
#         }
#       }
#       confidence: 0.4066888689994812
#     }
#   }
#   segment_label_annotations {
#     entity {
#       entity_id: "/m/0f2f9"
#       description: "television program"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#         }
#         end_time_offset {
#           seconds: 45
#           nanos: 40000000
#         }
#       }
#       confidence: 0.6629244089126587
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/083mg"
#       description: "walking"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/06ntj"
#       description: "sports"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#         }
#         end_time_offset {
#           seconds: 4
#           nanos: 760000000
#         }
#       }
#       confidence: 0.5601133704185486
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 6
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 8
#         }
#       }
#       confidence: 0.45920029282569885
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/06bm2"
#       description: "recreation"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#         }
#         end_time_offset {
#           seconds: 4
#           nanos: 760000000
#         }
#       }
#       confidence: 0.47077494859695435
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/01h8n0"
#       description: "conversation"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01lhf"
#       description: "communication"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 4
#           nanos: 800000000
#         }
#         end_time_offset {
#           seconds: 6
#         }
#       }
#       confidence: 0.44401291012763977
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 8
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 16
#           nanos: 120000000
#         }
#       }
#       confidence: 0.6200106143951416
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 16
#           nanos: 160000000
#         }
#         end_time_offset {
#           seconds: 18
#           nanos: 640000000
#         }
#       }
#       confidence: 0.4493437707424164
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 18
#           nanos: 680000000
#         }
#         end_time_offset {
#           seconds: 20
#           nanos: 40000000
#         }
#       }
#       confidence: 0.4022160768508911
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/0f2f9"
#       description: "television program"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 8
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 16
#           nanos: 120000000
#         }
#       }
#       confidence: 0.8613428473472595
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 16
#           nanos: 160000000
#         }
#         end_time_offset {
#           seconds: 18
#           nanos: 640000000
#         }
#       }
#       confidence: 0.8144142627716064
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/08t9c_"
#       description: "grass"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/05s2s"
#       description: "plant"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 4
#           nanos: 800000000
#         }
#         end_time_offset {
#           seconds: 6
#         }
#       }
#       confidence: 0.4319150149822235
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/07yv9"
#       description: "vehicle"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 20
#           nanos: 80000000
#         }
#         end_time_offset {
#           seconds: 26
#           nanos: 600000000
#         }
#       }
#       confidence: 0.44178536534309387
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/0jyfg"
#       description: "glasses"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 36
#           nanos: 440000000
#         }
#         end_time_offset {
#           seconds: 39
#           nanos: 360000000
#         }
#       }
#       confidence: 0.5659703016281128
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/01ckgp"
#       description: "interaction"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 4
#           nanos: 800000000
#         }
#         end_time_offset {
#           seconds: 6
#         }
#       }
#       confidence: 0.5736870765686035
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 8
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 16
#           nanos: 120000000
#         }
#       }
#       confidence: 0.7898109555244446
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 16
#           nanos: 160000000
#         }
#         end_time_offset {
#           seconds: 18
#           nanos: 640000000
#         }
#       }
#       confidence: 0.6374121308326721
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 20
#           nanos: 80000000
#         }
#         end_time_offset {
#           seconds: 26
#           nanos: 600000000
#         }
#       }
#       confidence: 0.6089750528335571
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/01b4q9"
#       description: "social group"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 6
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 8
#         }
#       }
#       confidence: 0.5221925377845764
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/03ykjs9"
#       description: "comedy"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 8
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 16
#           nanos: 120000000
#         }
#       }
#       confidence: 0.5883179903030396
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/09g5pq"
#       description: "people"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#         }
#         end_time_offset {
#           seconds: 4
#           nanos: 760000000
#         }
#       }
#       confidence: 0.6918299198150635
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 4
#           nanos: 800000000
#         }
#         end_time_offset {
#           seconds: 6
#         }
#       }
#       confidence: 0.5094974637031555
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/07j7r"
#       description: "tree"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/05s2s"
#       description: "plant"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#         }
#         end_time_offset {
#           seconds: 4
#           nanos: 760000000
#         }
#       }
#       confidence: 0.46258074045181274
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 4
#           nanos: 800000000
#         }
#         end_time_offset {
#           seconds: 6
#         }
#       }
#       confidence: 0.43474316596984863
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 6
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 8
#         }
#       }
#       confidence: 0.40725600719451904
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/015c4z"
#       description: "sitting"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 20
#           nanos: 80000000
#         }
#         end_time_offset {
#           seconds: 26
#           nanos: 600000000
#         }
#       }
#       confidence: 0.8370458483695984
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/05p553"
#       description: "comedy"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/g/12gh3rj_8"
#       description: "comedy"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/02vxn"
#       description: "film"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 8
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 16
#           nanos: 120000000
#         }
#       }
#       confidence: 0.5898033380508423
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/09kqc"
#       description: "humour"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 8
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 16
#           nanos: 120000000
#         }
#       }
#       confidence: 0.711929440498352
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 18
#           nanos: 680000000
#         }
#         end_time_offset {
#           seconds: 20
#           nanos: 40000000
#         }
#       }
#       confidence: 0.6891632080078125
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 36
#           nanos: 440000000
#         }
#         end_time_offset {
#           seconds: 39
#           nanos: 360000000
#         }
#       }
#       confidence: 0.4066888689994812
#     }
#   }
#   shot_label_annotations {
#     entity {
#       entity_id: "/m/01lqfm"
#       description: "public space"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01n32"
#       description: "city"
#       language_code: "en-US"
#     }
#     segments {
#       segment {
#         start_time_offset {
#         }
#         end_time_offset {
#           seconds: 4
#           nanos: 760000000
#         }
#       }
#       confidence: 0.7332445979118347
#     }
#     segments {
#       segment {
#         start_time_offset {
#           seconds: 6
#           nanos: 40000000
#         }
#         end_time_offset {
#           seconds: 8
#         }
#       }
#       confidence: 0.491739958524704
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/068jd"
#       description: "photograph"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.9491167664527893
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.9492044448852539
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.9538643956184387
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.9483444094657898
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.9477034211158752
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.9528136849403381
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.9494990706443787
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.9504711627960205
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/07bxq"
#       description: "tourism"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.4922598600387573
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.515313982963562
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.5465244650840759
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.4060356020927429
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.602708101272583
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/02fd6j"
#       description: "salaryman"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.4594448208808899
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.40314438939094543
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.4797390401363373
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.44847214221954346
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.5272827744483948
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.4934444725513458
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.4200716018676758
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.4142480492591858
#     }
#     frames {
#       time_offset {
#         seconds: 18
#         nanos: 175251000
#       }
#       confidence: 0.46494609117507935
#     }
#     frames {
#       time_offset {
#         seconds: 27
#         nanos: 498909000
#       }
#       confidence: 0.42572611570358276
#     }
#     frames {
#       time_offset {
#         seconds: 28
#         nanos: 662756000
#       }
#       confidence: 0.40087345242500305
#     }
#     frames {
#       time_offset {
#         seconds: 29
#         nanos: 747719000
#       }
#       confidence: 0.4076242744922638
#     }
#     frames {
#       time_offset {
#         seconds: 30
#         nanos: 837785000
#       }
#       confidence: 0.4171408712863922
#     }
#     frames {
#       time_offset {
#         seconds: 35
#         nanos: 917538000
#       }
#       confidence: 0.45942339301109314
#     }
#     frames {
#       time_offset {
#         seconds: 40
#         nanos: 166354000
#       }
#       confidence: 0.44760996103286743
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/02vxn"
#       description: "film"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/02jjt"
#       description: "entertainment"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.5356187224388123
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.4492886960506439
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.49777859449386597
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.4357181191444397
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.44450315833091736
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.41191330552101135
#     }
#     frames {
#       time_offset {
#         seconds: 27
#         nanos: 498909000
#       }
#       confidence: 0.45275846123695374
#     }
#     frames {
#       time_offset {
#         seconds: 28
#         nanos: 662756000
#       }
#       confidence: 0.41582152247428894
#     }
#     frames {
#       time_offset {
#         seconds: 29
#         nanos: 747719000
#       }
#       confidence: 0.4199548363685608
#     }
#     frames {
#       time_offset {
#         seconds: 30
#         nanos: 837785000
#       }
#       confidence: 0.46141132712364197
#     }
#     frames {
#       time_offset {
#         seconds: 31
#         nanos: 902157000
#       }
#       confidence: 0.42583274841308594
#     }
#     frames {
#       time_offset {
#         seconds: 33
#         nanos: 2263000
#       }
#       confidence: 0.42115017771720886
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 66492000
#       }
#       confidence: 0.4555038809776306
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 991171000
#       }
#       confidence: 0.42354658246040344
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/017r8p"
#       description: "pedestrian"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.6620361804962158
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.6244158148765564
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.4901971220970154
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.48265010118484497
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.4479142427444458
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/02hnx9"
#       description: "woody plant"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/05s2s"
#       description: "plant"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.8747810125350952
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.8761247396469116
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01_x9"
#       description: "campus"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/078x4m"
#       description: "location"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.5328076481819153
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0hr8"
#       description: "asphalt"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.45646932721138
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/083mg"
#       description: "walking"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/06ntj"
#       description: "sports"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.8534558415412903
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.9046940803527832
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.8454530835151672
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.8484049439430237
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.7490285038948059
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.7499446868896484
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.869463324546814
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.723762035369873
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.4560125172138214
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.46677613258361816
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.438049852848053
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0ds99lh"
#       description: "fun"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.6639721989631653
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.7152746915817261
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.6281396746635437
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.5914105176925659
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.5770626664161682
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.5521028637886047
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.6849552392959595
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.4381366968154907
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.5853721499443054
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.5659376382827759
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.6157223582267761
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.7026134133338928
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.4449354112148285
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.482774019241333
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.49437665939331055
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.6483960747718811
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.5484340190887451
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.6167810559272766
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.6525768637657166
#     }
#     frames {
#       time_offset {
#         seconds: 23
#         nanos: 290440000
#       }
#       confidence: 0.4529203474521637
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.6235426664352417
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.5694323182106018
#     }
#     frames {
#       time_offset {
#         seconds: 26
#         nanos: 423220000
#       }
#       confidence: 0.531470000743866
#     }
#     frames {
#       time_offset {
#         seconds: 36
#         nanos: 923075000
#       }
#       confidence: 0.4964187741279602
#     }
#     frames {
#       time_offset {
#         seconds: 38
#         nanos: 22873000
#       }
#       confidence: 0.40516290068626404
#     }
#     frames {
#       time_offset {
#         seconds: 39
#         nanos: 33411000
#       }
#       confidence: 0.43586888909339905
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0h8jxfl"
#       description: "vision care"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 36
#         nanos: 923075000
#       }
#       confidence: 0.7748005986213684
#     }
#     frames {
#       time_offset {
#         seconds: 38
#         nanos: 22873000
#       }
#       confidence: 0.705817461013794
#     }
#     frames {
#       time_offset {
#         seconds: 39
#         nanos: 33411000
#       }
#       confidence: 0.755824863910675
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/07j7r"
#       description: "tree"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/05s2s"
#       description: "plant"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.9270590543746948
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.9167121052742004
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.893718421459198
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.9390873312950134
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.9072105288505554
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.9210427403450012
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.9323979020118713
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.8670355677604675
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.6059060096740723
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.6908608675003052
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.8202793002128601
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.8709433674812317
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.8136532306671143
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.7433052659034729
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.5906873345375061
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.7870205044746399
#     }
#     frames {
#       time_offset {
#         seconds: 17
#         nanos: 199255000
#       }
#       confidence: 0.7259307503700256
#     }
#     frames {
#       time_offset {
#         seconds: 18
#         nanos: 175251000
#       }
#       confidence: 0.5624279379844666
#     }
#     frames {
#       time_offset {
#         seconds: 19
#         nanos: 342683000
#       }
#       confidence: 0.8068242073059082
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.8137821555137634
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.8381072282791138
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.8584269881248474
#     }
#     frames {
#       time_offset {
#         seconds: 23
#         nanos: 290440000
#       }
#       confidence: 0.7866319417953491
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.8782363533973694
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.8777949810028076
#     }
#     frames {
#       time_offset {
#         seconds: 26
#         nanos: 423220000
#       }
#       confidence: 0.8675023317337036
#     }
#     frames {
#       time_offset {
#         seconds: 27
#         nanos: 498909000
#       }
#       confidence: 0.4807150661945343
#     }
#     frames {
#       time_offset {
#         seconds: 28
#         nanos: 662756000
#       }
#       confidence: 0.47364693880081177
#     }
#     frames {
#       time_offset {
#         seconds: 29
#         nanos: 747719000
#       }
#       confidence: 0.43030765652656555
#     }
#     frames {
#       time_offset {
#         seconds: 30
#         nanos: 837785000
#       }
#       confidence: 0.4822215139865875
#     }
#     frames {
#       time_offset {
#         seconds: 31
#         nanos: 902157000
#       }
#       confidence: 0.43637728691101074
#     }
#     frames {
#       time_offset {
#         seconds: 33
#         nanos: 2263000
#       }
#       confidence: 0.570176362991333
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 66492000
#       }
#       confidence: 0.45649847388267517
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 991171000
#       }
#       confidence: 0.5461288094520569
#     }
#     frames {
#       time_offset {
#         seconds: 35
#         nanos: 917538000
#       }
#       confidence: 0.43801644444465637
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01qls"
#       description: "community"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/0qb7t"
#       description: "organization"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.7808958888053894
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.8492439389228821
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.8038729429244995
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.7911427617073059
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.7868069410324097
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.8413461446762085
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.778443455696106
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.7782599925994873
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/081pkj"
#       description: "event"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.5803533792495728
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.4959413707256317
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.6259685754776001
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.6096221208572388
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.7412013411521912
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.5803508162498474
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.4325724244117737
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.6245813369750977
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.7286301255226135
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.4835975468158722
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.428303986787796
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.5096489191055298
#     }
#     frames {
#       time_offset {
#         seconds: 19
#         nanos: 342683000
#       }
#       confidence: 0.47336649894714355
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0dzf4"
#       description: "arm"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/02p0tk3"
#       description: "human body"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 43
#         nanos: 253441000
#       }
#       confidence: 0.6777862310409546
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/04g3r"
#       description: "leisure"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.4035380184650421
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0bl0l"
#       description: "garden"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.5212811231613159
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.509097695350647
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.4473210573196411
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.4895878732204437
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01h6rj"
#       description: "military"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/0qb7t"
#       description: "organization"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 42
#         nanos: 104165000
#       }
#       confidence: 0.5022963285446167
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01n32"
#       description: "city"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/043rvww"
#       description: "geographical feature"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.6583710312843323
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.5748617053031921
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.45818647742271423
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.4326895773410797
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.4411259889602661
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01jm2n"
#       description: "walkway"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.7140016555786133
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.4369417130947113
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.4479803740978241
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/08t9c_"
#       description: "grass"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/05s2s"
#       description: "plant"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.8767950534820557
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.7687368988990784
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.750909686088562
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.8322387933731079
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.7538373470306396
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.8368343710899353
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.6446031332015991
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.5588304996490479
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.6693432927131653
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.5816681385040283
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.6684213876724243
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.7083021402359009
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.5629959106445312
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.5299737453460693
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.7836697101593018
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.7995824813842773
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.8290107250213623
#     }
#     frames {
#       time_offset {
#         seconds: 23
#         nanos: 290440000
#       }
#       confidence: 0.7585834264755249
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.8096803426742554
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.7698447108268738
#     }
#     frames {
#       time_offset {
#         seconds: 26
#         nanos: 423220000
#       }
#       confidence: 0.7713432312011719
#     }
#     frames {
#       time_offset {
#         seconds: 44
#         nanos: 160672000
#       }
#       confidence: 0.44998762011528015
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0jyfg"
#       description: "glasses"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 36
#         nanos: 923075000
#       }
#       confidence: 0.8408904671669006
#     }
#     frames {
#       time_offset {
#         seconds: 38
#         nanos: 22873000
#       }
#       confidence: 0.7543317675590515
#     }
#     frames {
#       time_offset {
#         seconds: 39
#         nanos: 33411000
#       }
#       confidence: 0.811075747013092
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0166ls"
#       description: "park"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.4906148910522461
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.4074312150478363
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.4422377943992615
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.44610631465911865
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/025s9qt"
#       description: "hug"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.40964362025260925
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0d4v4"
#       description: "window"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.43680766224861145
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01h8n0"
#       description: "conversation"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01lhf"
#       description: "communication"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.5398312211036682
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.5686124563217163
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.6643834710121155
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.701227605342865
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.7125529050827026
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.5170692205429077
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.5593647956848145
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.5212492346763611
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.7053257822990417
#     }
#     frames {
#       time_offset {
#         seconds: 17
#         nanos: 199255000
#       }
#       confidence: 0.5738994479179382
#     }
#     frames {
#       time_offset {
#         seconds: 18
#         nanos: 175251000
#       }
#       confidence: 0.5225695967674255
#     }
#     frames {
#       time_offset {
#         seconds: 19
#         nanos: 342683000
#       }
#       confidence: 0.5148030519485474
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.46480247378349304
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.4868518114089966
#     }
#     frames {
#       time_offset {
#         seconds: 23
#         nanos: 290440000
#       }
#       confidence: 0.43178197741508484
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.4046213626861572
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.5138723850250244
#     }
#     frames {
#       time_offset {
#         seconds: 26
#         nanos: 423220000
#       }
#       confidence: 0.47940635681152344
#     }
#     frames {
#       time_offset {
#         seconds: 27
#         nanos: 498909000
#       }
#       confidence: 0.5405151844024658
#     }
#     frames {
#       time_offset {
#         seconds: 28
#         nanos: 662756000
#       }
#       confidence: 0.4450344443321228
#     }
#     frames {
#       time_offset {
#         seconds: 29
#         nanos: 747719000
#       }
#       confidence: 0.45750701427459717
#     }
#     frames {
#       time_offset {
#         seconds: 30
#         nanos: 837785000
#       }
#       confidence: 0.4945228099822998
#     }
#     frames {
#       time_offset {
#         seconds: 31
#         nanos: 902157000
#       }
#       confidence: 0.42843571305274963
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 66492000
#       }
#       confidence: 0.6176683902740479
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 991171000
#       }
#       confidence: 0.4803129732608795
#     }
#     frames {
#       time_offset {
#         seconds: 35
#         nanos: 917538000
#       }
#       confidence: 0.5592003464698792
#     }
#     frames {
#       time_offset {
#         seconds: 36
#         nanos: 923075000
#       }
#       confidence: 0.4496307969093323
#     }
#     frames {
#       time_offset {
#         seconds: 38
#         nanos: 22873000
#       }
#       confidence: 0.4001506567001343
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/04rky"
#       description: "mammal"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/0jbk"
#       description: "animal"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.92533278465271
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.9236665964126587
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.9241633415222168
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.9233651161193848
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.9237131476402283
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.9251115918159485
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.9239586591720581
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.924683690071106
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.9232406616210938
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.9238513708114624
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/016c4t"
#       description: "ceremony"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/081pkj"
#       description: "event"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.4359877109527588
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/07pdzb4"
#       description: "baseball equipment"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 43
#         nanos: 253441000
#       }
#       confidence: 0.48187246918678284
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/05s2s"
#       description: "plant"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.8280594348907471
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.8114737272262573
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.7966246008872986
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.8031147718429565
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.7615704536437988
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.8637057542800903
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
# ...
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.7354345917701721
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.5968697667121887
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.69123774766922
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.408674955368042
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.44943347573280334
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.5652647614479065
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.5652424693107605
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.5776649713516235
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.48025405406951904
#     }
#     frames {
#       time_offset {
#         seconds: 26
#         nanos: 423220000
#       }
#       confidence: 0.4093905985355377
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01c8br"
#       description: "street"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/06gfj"
#       description: "road"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.4710204601287842
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/03gzqq"
#       description: "golf club"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.4023572504520416
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/01lqfm"
#       description: "public space"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01n32"
#       description: "city"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.9283366799354553
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.9269145131111145
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.9022817611694336
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.8988655805587769
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.852776050567627
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.8856126070022583
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/06bm2"
#       description: "recreation"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.7804970145225525
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.817649781703949
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.7688480615615845
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.7401396036148071
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.694291889667511
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.6925710439682007
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.7436257004737854
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.6458694338798523
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.633708655834198
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.5326792597770691
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.5472458004951477
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.6229487657546997
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.5229302048683167
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.5001027584075928
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.5509698987007141
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.6288866996765137
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.6649485230445862
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.6643826365470886
#     }
#     frames {
#       time_offset {
#         seconds: 23
#         nanos: 290440000
#       }
#       confidence: 0.6564361453056335
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.6654548645019531
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.6896064877510071
#     }
#     frames {
#       time_offset {
#         seconds: 26
#         nanos: 423220000
#       }
#       confidence: 0.6973454356193542
#     }
#     frames {
#       time_offset {
#         seconds: 27
#         nanos: 498909000
#       }
#       confidence: 0.4822075366973877
#     }
#     frames {
#       time_offset {
#         seconds: 29
#         nanos: 747719000
#       }
#       confidence: 0.4749017357826233
#     }
#     frames {
#       time_offset {
#         seconds: 30
#         nanos: 837785000
#       }
#       confidence: 0.4778299033641815
#     }
#     frames {
#       time_offset {
#         seconds: 31
#         nanos: 902157000
#       }
#       confidence: 0.470315158367157
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 66492000
#       }
#       confidence: 0.47782859206199646
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 991171000
#       }
#       confidence: 0.49539199471473694
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/035y33"
#       description: "official"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/01g317"
#       description: "person"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.45265132188796997
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.4083123803138733
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.5141998529434204
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.6007013320922852
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.5783237814903259
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.6791651248931885
#     }
#     frames {
#       time_offset {
#         seconds: 19
#         nanos: 342683000
#       }
#       confidence: 0.5118277072906494
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.4722346365451813
#     }
#     frames {
#       time_offset {
#         seconds: 36
#         nanos: 923075000
#       }
#       confidence: 0.4967058002948761
#     }
#     frames {
#       time_offset {
#         seconds: 38
#         nanos: 22873000
#       }
#       confidence: 0.44492223858833313
#     }
#     frames {
#       time_offset {
#         seconds: 40
#         nanos: 166354000
#       }
#       confidence: 0.6192905902862549
#     }
#     frames {
#       time_offset {
#         seconds: 42
#         nanos: 104165000
#       }
#       confidence: 0.5893008708953857
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/06gfj"
#       description: "road"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.6349665522575378
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.5056337118148804
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.5100313425064087
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.45736023783683777
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/032b3c"
#       description: "jacket"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/0h8krv8"
#       description: "top"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 31
#         nanos: 902157000
#       }
#       confidence: 0.4164268970489502
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0k4j"
#       description: "car"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/07yv9"
#       description: "vehicle"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.43919646739959717
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.4160826504230499
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.6011850833892822
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.7295359969139099
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.408887654542923
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.4313787817955017
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.5031254291534424
#     }
#     frames {
#       time_offset {
#         seconds: 20
#         nanos: 269384000
#       }
#       confidence: 0.8533920645713806
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.6894440650939941
#     }
#     frames {
#       time_offset {
#         seconds: 22
#         nanos: 144528000
#       }
#       confidence: 0.760921835899353
#     }
#     frames {
#       time_offset {
#         seconds: 23
#         nanos: 290440000
#       }
#       confidence: 0.7651097774505615
#     }
#     frames {
#       time_offset {
#         seconds: 24
#         nanos: 396657000
#       }
#       confidence: 0.6901673674583435
#     }
#     frames {
#       time_offset {
#         seconds: 25
#         nanos: 240026000
#       }
#       confidence: 0.6344160437583923
#     }
#     frames {
#       time_offset {
#         seconds: 26
#         nanos: 423220000
#       }
#       confidence: 0.7174774408340454
#     }
#     frames {
#       time_offset {
#         seconds: 31
#         nanos: 902157000
#       }
#       confidence: 0.4045937657356262
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 991171000
#       }
#       confidence: 0.45680689811706543
#     }
#     frames {
#       time_offset {
#         seconds: 44
#         nanos: 160672000
#       }
#       confidence: 0.6083019971847534
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/0gjyk"
#       description: "phenomenon"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 1
#         nanos: 798869000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 2
#         nanos: 808807000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 3
#         nanos: 706098000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 4
#         nanos: 660952000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 5
#         nanos: 696047000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 6
#         nanos: 725020000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 7
#         nanos: 795576000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 8
#         nanos: 995336000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 50188000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 10
#         nanos: 851273000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 11
#         nanos: 892254000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 12
#         nanos: 989991000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 13
#         nanos: 946229000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 15
#         nanos: 24478000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 16
#         nanos: 49651000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 17
#         nanos: 199255000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 18
#         nanos: 175251000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 19
#         nanos: 342683000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 30
#         nanos: 837785000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 33
#         nanos: 2263000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 34
#         nanos: 991171000
#       }
#       confidence: 0.7547649145126343
#     }
#     frames {
#       time_offset {
#         seconds: 35
#         nanos: 917538000
#       }
#       confidence: 0.7547649145126343
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/06pg22"
#       description: "snapshot"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/05wkw"
#       description: "photography"
#       language_code: "en-US"
#     }
#     category_entities {
#       entity_id: "/m/068jd"
#       description: "photograph"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.8176745176315308
#     }
#     frames {
#       time_offset {
#         seconds: 21
#         nanos: 271281000
#       }
#       confidence: 0.8176745176315308
#     }
#   }
#   frame_label_annotations {
#     entity {
#       entity_id: "/m/02vzx9"
#       description: "player"
#       language_code: "en-US"
#     }
#     frames {
#       time_offset {
#         nanos: 733627000
#       }
#       confidence: 0.5064893960952759
#     }
#   }
# }
# annotation_results {
#   input_uri: "/sherlock_movie/sherlock-mini-test.mp4"
#   error {
#     code: 13
#     message: "Speech transcription internal error: Invalid request argument(s)."
#   }
# }

# %% [markdown]
# # scene details

# %%
# needs work

# %% [markdown]
# # characters on screen (analogous to name - all)

# %% [markdown]
# ### get frames with people in them

# %%
def get_person_frames(result):
    frame_offsets = []
    frame_labels = result.annotation_results[0].frame_label_annotations
    for i, frame_label in enumerate(frame_labels):
        for category_entity in frame_label.category_entities:
            if category_entity.description == 'person':
                frame1 = frame_label.frames[0]
                time_offset = (frame1.time_offset.seconds + frame1.time_offset.nanos / 1e9)
                frame_offsets.append(time_offset)
    return(sorted(set(frame_offsets)))

# %%
# test
get_person_frames(test_result)
# Out:
# [0.733627,
#  4.660952,
#  5.696047,
#  8.995336,
#  16.049651,
#  20.269384,
#  36.923075,
#  42.104165,
#  43.253441]

# %% [markdown]
# ### extract image frames

# %%
# get image from video
def extract_image_from_video(video_input, name_output, time_stamp):
    ret = 'Error'
    try:
        ret = os.system('ffmpeg -i ' + video_input + ' -ss ' + time_stamp + ' -frames:v 1 ' + name_output)    
        # ret should = 0 if successful
        return ret
    except ValueError:
        return('Error in extract_image_from_video')

# crop around faces in extracted frames
def crop_image(input_image, output_image, start_x, start_y, width, height):
    
    input_img = Image.open(input_image)
    # crop with buffer space for mistakes & to for google vision to handle 
    start_with_buffer_x = int(start_x - np.ceil(width/2))
    start_with_buffer_y = int(start_y - np.ceil(height/2))
    width_with_buffer = int(start_x + width  + np.ceil(width/2))
    height_with_buffer = int(start_y + height  + np.ceil(height/2))

    box = (start_with_buffer_x, start_with_buffer_y, width_with_buffer, height_with_buffer)
    output_img = input_img.crop(box)
    output_img.save('../images/' + output_image + '.png')
    #return ('../images/' + output_image + '.png')
    return
    
# pass cropped images to google visioin
def detect_face(face_file, max_results=4):
    # return coordinates of face in frame
    client = vision.ImageAnnotatorClient()
    content = face_file.read()
    image = types.Image(content=content)

    # return face coords
    return client.face_detection(image=image).face_annotations

def highlight_faces(image, faces):
    # Draws a polygon around the faces, then saves to output_filename.
    faces_boxes = []
    im = Image.open(image)
    draw = ImageDraw.Draw(im)

    for face in faces:
        box = [(vertex.x, vertex.y)
               for vertex in face.bounding_poly.vertices]
        draw.line(box + [box[0]], width=5, fill='#00ff00')
        boxed_faces.append([box[0][0], box[0][1], box[1][0] - box[0][0], box[3][1] - box[0][1]])
    return (boxed_faces)

# %%
extract_image_from_video()

# %%
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-88-8402feaf8a40> in <module>()
# ----> 1 os.system()
#
# TypeError: Required argument 'command' (pos 1) not found

# %% [markdown]
# # camera angle

# %% [markdown]
# # indoor vs outdoor

# %% [markdown]
# # character speaking

# %% [markdown]
# # location

# %% [markdown]
# # music presence

# %% [markdown]
# # name - focus

# %% [markdown]
# # words on screen
